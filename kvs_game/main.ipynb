# %%
# Import libraries
import numpy as np
import pandas as pd
import os 
import cv2
import skimage
from PIL import Image
from ultralytics import YOLO
from matplotlib import pyplot as plt
import json
import time

# %% [markdown]
# ## Calculating Homography Matrix using keypoints coordinates

# %%
# Load the original image to get its dimensions
# change
original_image = cv2.imread('kvs.png')
# original_image = cv2.imread('trainingw.jpg')
original_height, original_width = original_image.shape[:2]

# New dimensions to which the frame is resized
# window_width = 854
# window_height = 480

# change
keypoints_path = "vocational_keypoints.json"
# keypoints_path = "trainingW.json"

window_width = original_width
window_height = original_height
print(window_width, window_height)

# Calculate scaling factors
x_scale = window_width / original_width
y_scale = window_height / original_height

# Load coordinates from JSON file
with open(f'coordinates/{keypoints_path}', 'r') as f:
    vocational_keypoints = json.load(f)

# Update coordinates with the scaling factor
for key, value in vocational_keypoints.items():
    if value:  # Check if the list is not empty
        x, y = value
        new_x = int(x * x_scale)
        new_y = int(y * y_scale)
        vocational_keypoints[key] = [new_x, new_y]

# Optionally, save the updated coordinates back to a file
with open('coordinates/updated.json', 'w') as f:
    json.dump(vocational_keypoints, f, indent=2)

with open('coordinates/updated.json', 'r') as f:
    vocational_keypoints = json.load(f)

with open('coordinates/map_keypoints.json', 'r') as f:
    map_keypoints = json.load(f)

# Filter out keypoints that are not visible
image_points = []
map_points = []
label_points = {}

i = 0

for key in vocational_keypoints:
    if vocational_keypoints[key] and map_keypoints[key]:  # Ensure keypoints are visible on both the frame and the map
        image_points.append(vocational_keypoints[key])
        map_points.append(map_keypoints[key])
        label_points[key] = i 
        i+=1

# Convert to NumPy arrays
image_points = np.array(image_points, dtype=np.float32)
map_points = np.array(map_points, dtype=np.float32)

# Calculate the homography matrix
H, status = cv2.findHomography(image_points, map_points, cv2.RANSAC, 5.0)
H
# Out:
# 2940 1912
# array([[   0.018917,     0.12276,     -250.61],
#        [  -0.097773,     -0.1908,      253.59],
#        [-1.1254e-05,  -0.0012991,           1]])

# %%
# Load the base map image
map_image_path = 'map.jpg'
base_map = cv2.imread(map_image_path)
if base_map is None:
    raise Exception(f"Map image {map_image_path} could not be loaded.")

height_of_map, width_of_map, _ = base_map.shape

# Apply the perspective transformation
transformed_image = cv2.warpPerspective(original_image, H, (width_of_map, height_of_map))

# Convert images from BGR to RGB
transformed_image_rgb = cv2.cvtColor(transformed_image, cv2.COLOR_BGR2RGB)
original_image_rgb = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)

# Set the figure size in inches (width, height)
plt.figure(figsize=(20, 10))  # Increase width to accommodate both images side by side

# Display the original image
plt.subplot(1, 2, 1)  # 1 row, 2 columns, 1st subplot
plt.imshow(original_image_rgb)
plt.title('Original Image')
plt.axis('off')  # Hide the axes

# Display the transformed image
plt.subplot(1, 2, 2)  # 1 row, 2 columns, 2nd subplot
plt.imshow(transformed_image_rgb)
plt.title('Transformed Image')
plt.axis('off')  # Hide the axes

# Save the figure
plt.savefig("homography.png", dpi=300, format='png', bbox_inches='tight', pad_inches=0.1)
# 'dpi=300' sets a high dots-per-inch (resolution)
# 'format=png' specifies the file format to use; PNG is lossless
# 'bbox_inches' and 'pad_inches' control the borders and padding around the saved figure

plt.show()

# %% [markdown]
# ## Loading weights and setting labels depending on the model

# %%
# import torch

# # Load the YOLO model
# model = torch.load('weights/best_nafie.pt', map_location=torch.device('cpu'))
# print(model)

# %%
# Load the YOLOv8 players detection model
# change

# weight = "weights/best.pt"
# labels_dic = {
#     0:"player",
#     1:"referee",
#     2:"ball",
# }

weight = "weights/best (1).pt"
labels_dic = {
    0:"Player team left",
    1:"Player team right",
    2:"Goalkeeper team left",
    3:"Goalkeeper team right",
    4:"Ball",
    5:"Main referee",
    6:"Side referee",
    7:"Staff members",
}

model_players = YOLO(weight)

# %% [markdown]
# ## Set Parameters

# %%
# Initialize frame counter
frame_nbr = 0

# Set confidence thresholds for players and field keypoints detections
player_model_conf_thresh = 0.50

# Set variable to record the time when we processed last frame 
prev_frame_time = 0
# Set variable to record the time at which we processed current frame 
new_frame_time = 0

# Store the ball track history
ball_track_history = {'src':[],
                      'dst':[]
}

# Count consecutive frames with no ball detected
nbr_frames_no_ball = 0
# Threshold for number of frames with no ball to reset ball track (frames)
nbr_frames_no_ball_thresh = 30
# Distance threshold for ball tracking (pixels)
ball_track_dist_thresh = 100
# Maximum ball track length (detections)
max_track_length = 35

# Initialize counters and storage for class detections
class_detection_counts = {}

# %% [markdown]
# ## Choosing video and finding team colors

# %%
# change

video_path = './videos/KVS_H1_TEST.mp4'
# video_path = './videos/TrainingW_TEST.mp4'

tac_map = cv2.imread('./map.jpg')

# %% [markdown]
# #### K-means clustering

# %%
img = original_image
hsv = cv2.cvtColor(original_image, cv2.COLOR_BGR2HSV)

# Define a large range of green color in HSV
lower_green = np.array([30, 40, 40])
upper_green = np.array([80, 255, 255])

# Threshold the HSV image to get only green colors
mask = cv2.inRange(hsv, lower_green, upper_green)

# Calculate the mean value of the pixels that are not masked
masked_img = cv2.bitwise_and(img, img, mask=mask)
plt.imshow(masked_img)
grass_color = cv2.mean(img, mask=mask)
grass_color = grass_color[:3]
print("Grass BGR color: ", grass_color)
# Out:
# Grass BGR color:  (57.94699422747249, 106.726676177751, 80.14014433581738)

# %%
# Perform detection
results_players = model_players(img, conf=player_model_conf_thresh)

# Extract detection data
bboxes_p = results_players[0].boxes.xyxy.cpu().numpy() 
labels_p = list(results_players[0].boxes.cls.cpu().numpy())
confs_p = list(results_players[0].boxes.conf.cpu().numpy())

kits_colors = []
grass_hsv = cv2.cvtColor(np.uint8([[list(grass_color)]]), cv2.COLOR_BGR2HSV)

# Process each detection
for i, label in enumerate(labels_p):
    if label == 0:  # Assuming '0' is the label for players
        x1, y1, x2, y2 = map(int, bboxes_p[i])
        player_img = img[y1:y2, x1:x2]
        hsv = cv2.cvtColor(player_img, cv2.COLOR_BGR2HSV)

        # Adjust the green range based on the average grass color
        lower_green = np.array([grass_hsv[0, 0, 0] - 10, 40, 40])
        upper_green = np.array([grass_hsv[0, 0, 0] + 10, 255, 255])
        mask = cv2.inRange(hsv, lower_green, upper_green)
        mask = cv2.bitwise_not(mask)

        # Apply a mask to get the upper half of the player (typically where the kit is most visible)
        upper_mask = np.zeros(player_img.shape[:2], np.uint8)
        upper_mask[0:player_img.shape[0]//2, :] = 255
        mask = cv2.bitwise_and(mask, upper_mask)
        masked_img = cv2.bitwise_and(player_img, player_img, mask=mask)

        # Calculate the mean color of the player's kit
        player_kit_color = np.array(cv2.mean(player_img, mask=mask)[:3])
        kits_colors.append(player_kit_color)

        # Display results
        plt.imshow(cv2.cvtColor(masked_img, cv2.COLOR_BGR2RGB))
        plt.title(f"Player Kit Color: {player_kit_color}")
        plt.show()
# Out:
# 0: 544x800 9 playerss, 392.0ms
# Speed: 4.1ms preprocess, 392.0ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 800)

# %%
import numpy as np
from sklearn.cluster import KMeans
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")

# Assuming kits_colors contains the BGR colors of the player kits extracted previously
kits_colors = np.array(kits_colors)

# Apply K-means clustering to classify the kits into two distinct colors
kits_kmeans = KMeans(n_clusters=2)
kits_kmeans.fit(kits_colors)

# Convert the BGR color format to RGB for visualization
kits_colors_rgb = kits_colors[:, [2, 1, 0]]  # Reversing BGR to RGB
cluster_centers_rgb = kits_kmeans.cluster_centers_[:, [2, 1, 0]]

# Create a 3D scatter plot of the kit colors
fig = px.scatter_3d(
    x=kits_colors_rgb[:, 0],
    y=kits_colors_rgb[:, 1],
    z=kits_colors_rgb[:, 2],
    range_x=[0, 255],
    range_y=[0, 255],
    range_z=[0, 255],
    title="Kits Colors Clustering",
    color=kits_kmeans.labels_
)

# Add the cluster centers to the plot
fig.add_scatter3d(
    x=cluster_centers_rgb[:, 0],
    y=cluster_centers_rgb[:, 1],
    z=cluster_centers_rgb[:, 2],
    mode='markers',
    marker=dict(color='black', size=10, symbol='cross'),
    name='Cluster Centers'
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 12
#      10 # Apply K-means clustering to classify the kits into two distinct colors
#      11 kits_kmeans = KMeans(n_clusters=2)
# ---> 12 kits_kmeans.fit(kits_colors)
#      14 # Convert the BGR color format to RGB for visualization
#      15 kits_colors_rgb = kits_colors[:, [2, 1, 0]]  # Reversing BGR to RGB
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1471, in KMeans.fit(self, X, y, sample_weight)
#    1443 @_fit_context(prefer_skip_nested_validation=True)
#    1444 def fit(self, X, y=None, sample_weight=None):
#    1445     """Compute k-means clustering.
#    1446
#    1447     Parameters
#    (...)
#    1469         Fitted estimator.
#    1470     """
# -> 1471     X = self._validate_data(
#    1472         X,
#    1473         accept_sparse="csr",
#    1474         dtype=[np.float64, np.float32],
#    1475         order="C",
#    1476         copy=self.copy_x,
#    1477         accept_large_sparse=False,
#    1478     )
#    1480     self._check_params_vs_input(X)
#    1482     random_state = check_random_state(self.random_state)
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/base.py:604, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     602         out = X, y
#     603 elif not no_val_X and no_val_y:
# --> 604     out = check_array(X, input_name="X", **check_params)
#     605 elif no_val_X and not no_val_y:
#     606     out = _check_y(y, **check_params)
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:940, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     938     # If input is 1D raise error
#     939     if array.ndim == 1:
# --> 940         raise ValueError(
#     941             "Expected 2D array, got 1D array instead:\narray={}.\n"
#     942             "Reshape your data either using array.reshape(-1, 1) if "
#     943             "your data has a single feature or array.reshape(1, -1) "
#     944             "if it contains a single sample.".format(array)
#     945         )
#     947 if dtype_numeric and hasattr(array.dtype, "kind") and array.dtype.kind in "USV":
#     948     raise ValueError(
#     949         "dtype='numeric' is not compatible with arrays of bytes/strings."
#     950         "Convert your data to numeric values explicitly instead."
#     951     )
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
# change
Team1 = "Team1"
Team2 = "Team2"

colors_dic = {
    f"{Team1}": [tuple(map(int, cluster_centers_rgb[0]))],  # Convert the first centroid to integer values
    f"{Team2}": [tuple(map(int, cluster_centers_rgb[1]))]   # Convert the second centroid to integer values
}

# Define team colors
nbr_team_colors = 1

# %%
colors_dic
# Out:
# {'Team1': [(106, 97, 66)], 'Team2': [(98, 120, 106)]}

# %% [markdown]
# #### Manual method

# %%
# change

# colors_dic = {
#     "Purple":[(105,105,160), (105,105,160)], # DKU Colors (Players kit color, GK kit color)
#     "Yellow":[(200,200,100), (200,200,100)] # KVS Colors (Players kit color, GK kit color)
# }
# colors_list = colors_dic["Purple"]+colors_dic["Yellow"] # Define color list to be used for detected player team prediction

# colors_dic = {
#     "DKU":[(200,200,200), (115,144,98)], # DKU Colors (Players kit color, GK kit color)
#     "KVS":[(120,52,47), (47,103,43)] # KVS Colors (Players kit color, GK kit color)
# }

# %%
colors_list = colors_dic[f"{Team1}"]+colors_dic[f"{Team2}"] # Define color list to be used for detected player team prediction
color_list_lab = [skimage.color.rgb2lab([i/255 for i in c]) for c in colors_list] # Converting color_list to L*a*b* space

# %% [markdown]
# ## Running the model

# %%
frame_save_path = 'saved_frames'
os.makedirs(frame_save_path, exist_ok=True)  # Create the directory if it doesn't exist

# Open video file
cap = cv2.VideoCapture(video_path)

# Loop through the video frames
while cap.isOpened():

    # Read a frame from the video
    success, frame = cap.read()
    if not success:
        print("Failed to read frame or end of video reached.")
        break  # Exit the loop if no frame is read or end of video is reached

    frame = cv2.resize(frame, (window_width, window_height))

    # Save each frame to the folder
    frame_nbr += 1
    
    # Save number of detections per frame
    current_frame_class_counts = {}

    # Reset tactical map image for each new frame
    tac_map_copy = tac_map.copy()
    # Define the transparency factor (alpha)
    alpha = 0.5  # 50% transparency
    beta = (1.0 - alpha)  # Weight of the second array elements

    # Create a black background of the same size as the tactical map
    background = np.zeros_like(tac_map_copy)

    # Blend the tactical map with the black background
    tac_map_copy = cv2.addWeighted(tac_map_copy, alpha, background, beta, 0)

    # Reset ball tracks
    if nbr_frames_no_ball>nbr_frames_no_ball_thresh:
            ball_track_history['dst'] = []
            ball_track_history['src'] = []

    # Process the frame if it was successfuly read
    if success:
        
        #################### Part 1 ####################
        # Object Detection & Coordiante Transofrmation #
        ################################################

        # Run YOLOv8 players inference on the frame
        results_players = model_players(frame, conf=player_model_conf_thresh)

        ## Extract detections information
        bboxes_p = results_players[0].boxes.xyxy.cpu().numpy()                # Detected players, referees and ball (x,y,x,y) bounding boxes
        bboxes_p_c = results_players[0].boxes.xywh.cpu().numpy()              # Detected players, referees and ball (x,y,w,h) bounding boxes    
        labels_p = list(results_players[0].boxes.cls.cpu().numpy())           # Detected players, referees and ball labels list
        confs_p = list(results_players[0].boxes.conf.cpu().numpy())           # Detected players, referees and ball confidence level

        # change
        # bboxes_p_c_0 = bboxes_p_c[[i==0 for i in labels_p],:]                 # Get bounding boxes information (x,y,w,h) of detected players (label 0)
        # bboxes_p_c_2 = bboxes_p_c[[i==2 for i in labels_p],:]                 # Get bounding boxes information (x,y,w,h) of detected ball(s) (label 2)
        bboxes_p_c_0 = bboxes_p_c[[i==0 or i==1 or i==2 or i==3 for i in labels_p],:]  # Get bounding boxes information (x,y,w,h) of detected players (label 0)
        bboxes_p_c_2 = bboxes_p_c[[i==4 for i in labels_p],:]                          # Get bounding boxes information (x,y,w,h) of detected ball(s) (label 2)

        # Get coordinates of detected players on frame (x_cencter, y_center+h/2)
        detected_ppos_src_pts = bboxes_p_c_0[:,:2]  + np.array([[0]*bboxes_p_c_0.shape[0], bboxes_p_c_0[:,3]/2]).transpose()
        # Get coordinates of the first detected ball (x_center, y_center)
        detected_ball_src_pos = bboxes_p_c_2[0,:2] if bboxes_p_c_2.shape[0]>0 else None

        # Transform players coordinates from frame plane to tactical map plance using the calculated Homography matrix
        pred_dst_pts = []                                                     # Initialize players tactical map coordiantes list
        for pt in detected_ppos_src_pts:     
            # print("Coor:", pt)
            pt = np.append(np.array(pt), np.array([1]), axis=0)               # Covert to homogeneous coordiantes
            dest_point = np.matmul(H, np.transpose(pt))                       # Apply homography transofrmation
            dest_point = dest_point/dest_point[2]           
            # print("map:", list(np.transpose(dest_point)[:2]))
            pred_dst_pts.append(list(np.transpose(dest_point)[:2]))           # Update players tactical map coordiantes list
        pred_dst_pts = np.array(pred_dst_pts)

        # Transform ball coordinates from frame plane to tactical map plane using the calculated Homography matrix
        if detected_ball_src_pos is not None:
            pt = np.append(np.array(detected_ball_src_pos), np.array([1]), axis=0)
            dest_point = np.matmul(H, np.transpose(pt))
            dest_point = dest_point/dest_point[2]
            detected_ball_dst_pos = np.transpose(dest_point)

            # Update track ball position history
            if len(ball_track_history['src'])>0 :
                if np.linalg.norm(detected_ball_src_pos-ball_track_history['src'][-1])<ball_track_dist_thresh:
                    ball_track_history['src'].append((int(detected_ball_src_pos[0]), int(detected_ball_src_pos[1])))
                    ball_track_history['dst'].append((int(detected_ball_dst_pos[0]), int(detected_ball_dst_pos[1])))
                else:
                    ball_track_history['src']=[(int(detected_ball_src_pos[0]), int(detected_ball_src_pos[1]))]
                    ball_track_history['dst']=[(int(detected_ball_dst_pos[0]), int(detected_ball_dst_pos[1]))]
            else:
                ball_track_history['src'].append((int(detected_ball_src_pos[0]), int(detected_ball_src_pos[1])))
                ball_track_history['dst'].append((int(detected_ball_dst_pos[0]), int(detected_ball_dst_pos[1])))
                
        # Remove oldest tracked ball postion if track exceedes threshold
        if len(ball_track_history) > max_track_length:
                ball_track_history['src'].pop(0)
                ball_track_history['dst'].pop(0)

        # After detection, populate the count for each detected class in the current frame
        for label in labels_p:
            if label in current_frame_class_counts:
                current_frame_class_counts[label] += 1
            else:
                current_frame_class_counts[label] = 1

        # Update the total detections for each class
        for label, count in current_frame_class_counts.items():
            if label in class_detection_counts:
                class_detection_counts[label] += count
            else:
                class_detection_counts[label] = count

        ######### Part 2 ########## 
        # Players Team Prediction #
        ###########################

        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)                    # Convert frame to RGB
        obj_palette_list = []                                                 # Initialize players color palette list
        palette_interval = (0,5)                                              # Color interval to extract from dominant colors palette (1rd to 5th color)
        annotated_frame = frame                                               # Create annotated frame 

        ## Loop over detected players (label 0) and extract dominant colors palette based on defined interval
        for i, j in enumerate(list(results_players[0].boxes.cls.cpu().numpy())):
            if int(j) == 0 or int(j) == 1 or int(j) == 2 or int(j) == 3:
            # if int(j) == 0:
            # change
                bbox = results_players[0].boxes.xyxy.cpu().numpy()[i,:]                         # Get bbox info (x,y,x,y)
                obj_img = frame_rgb[int(bbox[1]):int(bbox[3]), int(bbox[0]):int(bbox[2])]       # Crop bbox out of the frame
                obj_img_w, obj_img_h = obj_img.shape[1], obj_img.shape[0]

                center_filter_x1 = np.max([(obj_img_w//2)-(obj_img_w//5), 1])
                center_filter_x2 = (obj_img_w//2)+(obj_img_w//5)
                center_filter_y1 = np.max([(obj_img_h//3)-(obj_img_h//5), 1])
                center_filter_y2 = (obj_img_h//3)+(obj_img_h//5)
                center_filter = obj_img[center_filter_y1:center_filter_y2, 
                                        center_filter_x1:center_filter_x2]

                # obj_pil_img = Image.fromarray(np.uint8(center_filter))                        # Convert to pillow image
                obj_pil_img = Image.fromarray(np.uint8(center_filter))                          # Convert to pillow image

                reduced = obj_pil_img.convert("P", palette=Image.Palette.WEB)                   # Convert to web palette (216 colors)
                palette = reduced.getpalette()                                                  # Get palette as [r,g,b,r,g,b,...]
                palette = [palette[3*n:3*n+3] for n in range(256)]                              # Group 3 by 3 = [[r,g,b],[r,g,b],...]
                color_count = [(n, palette[m]) for n,m in reduced.getcolors()]                  # Create list of palette colors with their frequency
                RGB_df = pd.DataFrame(color_count, columns = ['cnt', 'RGB']).sort_values(       # Create dataframe based on defined palette interval
                                      by = 'cnt', ascending = False).iloc[
                                          palette_interval[0]:palette_interval[1],:]
                palette = list(RGB_df.RGB)                                                      # Convert palette to list (for faster processing)
                annotated_frame = cv2.rectangle(annotated_frame,                                # Add center filter bbox annotations
                                                (int(bbox[0])+center_filter_x1, 
                                                 int(bbox[1])+ center_filter_y1),  
                                                (int(bbox[0])+center_filter_x2, 
                                                 int(bbox[1])+center_filter_y2), (0,0,0), 2)
                
                # Update detected players color palette list
                obj_palette_list.append(palette)
        
        ## Calculate distances between each color from every detected player color palette and the predefined teams colors
        players_distance_features = []
        # Loop over detected players extracted color palettes
        for palette in obj_palette_list:
            palette_distance = []
            palette_lab = [skimage.color.rgb2lab([i/255 for i in color]) for color in palette]  # Convert colors to L*a*b* space
            # Loop over colors in palette
            for color in palette_lab:
                distance_list = []
                # Loop over predefined list of teams colors
                for c in color_list_lab:
                    distance = skimage.color.deltaE_cie76(color, c)                             # Calculate Euclidean distance in Lab color space
                    distance_list.append(distance)                                              # Update distance list for current color
                palette_distance.append(distance_list)                                          # Update distance list for current palette
            players_distance_features.append(palette_distance)                                  # Update distance features list

        ## Predict detected players teams based on distance features
        players_teams_list = []
        # Loop over players distance features
        for distance_feats in players_distance_features:
            vote_list=[]
            # Loop over distances for each color 
            for dist_list in distance_feats:
                team_idx = dist_list.index(min(dist_list))//nbr_team_colors                     # Assign team index for current color based on min distance
                vote_list.append(team_idx)                                                      # Update vote voting list with current color team prediction
            players_teams_list.append(max(vote_list, key=vote_list.count))                      # Predict current player team by vote counting

        #################### Part 3 #####################
        # Updated Frame & Tactical Map With Annotations #
        #################################################

        ball_color_bgr = (0,0,255)                                                              # Color (GBR) for ball annotation on tactical map
        j=0                                                                                     # Initializing counter of detected players
        palette_box_size = 5                                                                    # Set color box size in pixels (for display)

        # Loop over all detected object by players detection model
        for i in range(bboxes_p.shape[0]):
            conf = confs_p[i]                                                                   # Get confidence of current detected object
            # change
            # if labels_p[i]==0:                                                                  # Display annotation for detected players (label 0)
            if labels_p[i]==0 or labels_p[i]==1 or labels_p[i]==2 or labels_p[i]==3:
                # Display extracted color palette for each detected player
                palette = obj_palette_list[j]                                                               # Get color palette of the detected player
                for k, c in enumerate(palette):
                    c_bgr = c[::-1]                                                                         # Convert color to BGR
                    annotated_frame = cv2.rectangle(annotated_frame, (int(bboxes_p[i,2])+3,                 # Add color palette annotation on frame
                                                            int(bboxes_p[i,1])+k*palette_box_size),
                                                            (int(bboxes_p[i,2])+palette_box_size,
                                                            int(bboxes_p[i,1])+(palette_box_size)*(k+1)),
                                                              c_bgr, -1)

                team_name = list(colors_dic.keys())[players_teams_list[j]]                                  # Get detected player team prediction
                color_rgb = colors_dic[team_name][0]                                                        # Get detected player team color
                color_bgr = color_rgb[::-1]                                                                 # Convert color to bgr

                annotated_frame = cv2.rectangle(annotated_frame, (int(bboxes_p[i,0]), int(bboxes_p[i,1])),  # Add bbox annotations with team colors
                                                (int(bboxes_p[i,2]), int(bboxes_p[i,3])), color_bgr, 1)
                
                cv2.putText(annotated_frame, team_name + f" {conf:.2f}",                                    # Add team name annotations
                             (int(bboxes_p[i,0]), int(bboxes_p[i,1])-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5,
                               color_bgr, 2)
                
                if color_bgr == (255, 255, 255):
                    color_bgr = (0,0,0) 
                
                # Add tactical map player postion color coded annotation
                tac_map_copy = cv2.circle(tac_map_copy, (abs(int(pred_dst_pts[j][0])),abs(int(pred_dst_pts[j][1]))),
                                          radius=5, color=color_bgr , thickness=-1)          
                j+=1                                                                                        # Update players counter
                
            else:                                                                                            # Display annotation for other detections (label 1, 2)
                annotated_frame = cv2.rectangle(annotated_frame, (int(bboxes_p[i,0]), int(bboxes_p[i,1])),  
                                                 (int(bboxes_p[i,2]), int(bboxes_p[i,3])), (255,255,255), 4) # Add white colored bbox annotations
                cv2.putText(annotated_frame, labels_dic[int(labels_p[i])] + f" {conf:.2f}",
                            (int(bboxes_p[i,0]), int(bboxes_p[i,1])-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5,
                              (255,255,255), 2)                                                              # Add white colored label text annotations
                print(labels_dic[int(labels_p[i])])
                # Add tactical map ball postion annotation if detected
                if detected_ball_src_pos is not None:
                    tac_map_copy = cv2.circle(tac_map_copy, (int(detected_ball_dst_pos[0]), 
                                                             int(detected_ball_dst_pos[1])), radius=5, 
                                                             color=ball_color_bgr, thickness=3)
        
        # Plot the ball tracks on tactical map
        if len(ball_track_history['src'])>0:
            points = np.hstack(ball_track_history['dst']).astype(np.int32).reshape((-1, 1, 2))
            tac_map_copy = cv2.polylines(tac_map_copy, [points], isClosed=False, color=(0, 0, 100), thickness=2)
        
        # Combine annotated frame and tactical map in one image with colored border separation
        border_color = [255,255,255]                                                                        # Set border color (BGR)
        annotated_frame=cv2.copyMakeBorder(annotated_frame, 40, 10, 10, 10,                                 # Add borders to annotated frame
                                            cv2.BORDER_CONSTANT, value=border_color)
        tac_map_copy = cv2.rotate(tac_map_copy, cv2.ROTATE_90_COUNTERCLOCKWISE)                             # 90 degrees rotation

        # Calculate the position to start the overlay (top right corner)
        start_y = 50
        start_x = annotated_frame.shape[1] - tac_map_copy.shape[1] - 50 # Start at the right edge of the annotated_frame

        annotated_frame[start_y:start_y + tac_map_copy.shape[0], start_x:start_x + tac_map_copy.shape[1]] = tac_map_copy

        final_img = annotated_frame

        ## Add info annotation
        cv2.putText(final_img, "Press 'p' to pause & 'q' to quit", (300,30), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0,0,0), 2)

        new_frame_time = time.time()                                                                        # Get time after finished processing current frame
        fps = 1/(new_frame_time-prev_frame_time)                                                            # Calculate FPS as 1/(frame proceesing duration)
        prev_frame_time = new_frame_time                                                                    # Save current time to be used in next frame
        cv2.putText(final_img, "FPS: " + str(int(fps)), (20,30), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0,0,0), 2)
        
        # Display the final annotated frame
        cv2.imshow("YOLOv8 Players and Field Keypoints Detection with Team Prediction and Tactical Map",    
                    final_img)
        
        frame_filename = os.path.join(frame_save_path, f'frame_{frame_nbr:04d}.jpg')
        cv2.imwrite(frame_filename, final_img)  # Save the frame as JPEG file

        # Treat keyboard user inputs ("p" for pause/unpause & "q" for quit)
        key = cv2.waitKey(1)
        # Break the loop if 'q' is pressed
        if key == ord("q"):
            break
        if key == ord('p'):
            cv2.waitKey(-1) #wait until any key is pressed
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 544x800 14 playerss, 1 referee, 410.4ms
# Speed: 3.9ms preprocess, 410.4ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 1 referee, 418.3ms
# Speed: 4.4ms preprocess, 418.3ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 1 referee, 490.8ms
# Speed: 3.4ms preprocess, 490.8ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 20 playerss, 1 referee, 397.1ms
# Speed: 3.5ms preprocess, 397.1ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 2 referees, 439.7ms
# Speed: 3.3ms preprocess, 439.7ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 2 referees, 423.3ms
# Speed: 3.9ms preprocess, 423.3ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 19 playerss, 1 referee, 355.1ms
# Speed: 3.5ms preprocess, 355.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 19 playerss, 1 referee, 381.8ms
# Speed: 3.4ms preprocess, 381.8ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 1 referee, 359.2ms
# Speed: 3.3ms preprocess, 359.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 348.6ms
# Speed: 3.2ms preprocess, 348.6ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 1 referee, 341.8ms
# Speed: 3.4ms preprocess, 341.8ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 2 referees, 345.4ms
# Speed: 3.2ms preprocess, 345.4ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 2 referees, 340.6ms
# Speed: 3.4ms preprocess, 340.6ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 2 referees, 344.3ms
# Speed: 3.3ms preprocess, 344.3ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 12 playerss, 2 referees, 353.0ms
# Speed: 2.9ms preprocess, 353.0ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 2 referees, 360.3ms
# Speed: 3.3ms preprocess, 360.3ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 1 referee, 342.3ms
# Speed: 3.4ms preprocess, 342.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 1 referee, 341.0ms
# Speed: 3.1ms preprocess, 341.0ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 341.7ms
# Speed: 3.1ms preprocess, 341.7ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 361.9ms
# Speed: 3.6ms preprocess, 361.9ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 1 referee, 342.7ms
# Speed: 3.2ms preprocess, 342.7ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 1 referee, 344.0ms
# Speed: 3.2ms preprocess, 344.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 1 referee, 348.1ms
# Speed: 3.2ms preprocess, 348.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 2 referees, 369.2ms
# Speed: 3.2ms preprocess, 369.2ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 19 playerss, 2 referees, 437.7ms
# Speed: 3.5ms preprocess, 437.7ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 2 referees, 378.3ms
# Speed: 3.4ms preprocess, 378.3ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 1 referee, 414.2ms
# Speed: 3.8ms preprocess, 414.2ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 374.8ms
# Speed: 3.5ms preprocess, 374.8ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 1 referee, 371.7ms
# Speed: 3.3ms preprocess, 371.7ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 1 referee, 464.1ms
# Speed: 3.3ms preprocess, 464.1ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 422.5ms
# Speed: 3.6ms preprocess, 422.5ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 355.6ms
# Speed: 3.2ms preprocess, 355.6ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 19 playerss, 365.0ms
# Speed: 2.9ms preprocess, 365.0ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 19 playerss, 355.3ms
# Speed: 3.3ms preprocess, 355.3ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 20 playerss, 367.0ms
# Speed: 3.1ms preprocess, 367.0ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 19 playerss, 364.7ms
# Speed: 3.4ms preprocess, 364.7ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 356.0ms
# Speed: 3.3ms preprocess, 356.0ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 375.0ms
# Speed: 3.3ms preprocess, 375.0ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 407.9ms
# Speed: 3.3ms preprocess, 407.9ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 363.4ms
# Speed: 3.3ms preprocess, 363.4ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 367.5ms
# Speed: 3.2ms preprocess, 367.5ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 374.1ms
# Speed: 3.5ms preprocess, 374.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 362.1ms
# Speed: 3.0ms preprocess, 362.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 390.3ms
# Speed: 3.2ms preprocess, 390.3ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 376.1ms
# Speed: 3.4ms preprocess, 376.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 381.0ms
# Speed: 3.8ms preprocess, 381.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 363.2ms
# Speed: 3.1ms preprocess, 363.2ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 351.3ms
# Speed: 3.1ms preprocess, 351.3ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 420.4ms
# Speed: 3.2ms preprocess, 420.4ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 378.1ms
# Speed: 3.8ms preprocess, 378.1ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 361.8ms
# Speed: 3.0ms preprocess, 361.8ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 346.2ms
# Speed: 3.1ms preprocess, 346.2ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 12 playerss, 528.1ms
# Speed: 3.1ms preprocess, 528.1ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 10 playerss, 359.4ms
# Speed: 3.3ms preprocess, 359.4ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 348.8ms
# Speed: 3.1ms preprocess, 348.8ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 354.6ms
# Speed: 3.3ms preprocess, 354.6ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 361.8ms
# Speed: 3.2ms preprocess, 361.8ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 19 playerss, 358.4ms
# Speed: 3.3ms preprocess, 358.4ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 375.8ms
# Speed: 3.5ms preprocess, 375.8ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 19 playerss, 365.2ms
# Speed: 3.2ms preprocess, 365.2ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 20 playerss, 355.8ms
# Speed: 3.1ms preprocess, 355.8ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 20 playerss, 359.5ms
# Speed: 3.1ms preprocess, 359.5ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 368.7ms
# Speed: 3.1ms preprocess, 368.7ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 20 playerss, 370.9ms
# Speed: 3.1ms preprocess, 370.9ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 375.6ms
# Speed: 3.6ms preprocess, 375.6ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 355.5ms
# Speed: 3.5ms preprocess, 355.5ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 383.2ms
# Speed: 3.1ms preprocess, 383.2ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 390.4ms
# Speed: 3.4ms preprocess, 390.4ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 373.1ms
# Speed: 3.5ms preprocess, 373.1ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 354.0ms
# Speed: 3.3ms preprocess, 354.0ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 347.5ms
# Speed: 3.3ms preprocess, 347.5ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 353.4ms
# Speed: 3.1ms preprocess, 353.4ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 1 referee, 355.9ms
# Speed: 3.1ms preprocess, 355.9ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 1 referee, 415.1ms
# Speed: 3.1ms preprocess, 415.1ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 1 referee, 363.9ms
# Speed: 3.1ms preprocess, 363.9ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 1 referee, 346.2ms
# Speed: 3.1ms preprocess, 346.2ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 1 referee, 354.5ms
# Speed: 3.4ms preprocess, 354.5ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 1 referee, 364.6ms
# Speed: 3.1ms preprocess, 364.6ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 1 referee, 368.8ms
# Speed: 3.0ms preprocess, 368.8ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 1 referee, 350.6ms
# Speed: 3.1ms preprocess, 350.6ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 1 referee, 385.7ms
# Speed: 3.3ms preprocess, 385.7ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 379.1ms
# Speed: 3.3ms preprocess, 379.1ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 1 referee, 358.1ms
# Speed: 3.4ms preprocess, 358.1ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 1 referee, 348.3ms
# Speed: 3.3ms preprocess, 348.3ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 1 referee, 354.0ms
# Speed: 3.2ms preprocess, 354.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 1 referee, 353.7ms
# Speed: 3.2ms preprocess, 353.7ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 1 referee, 374.8ms
# Speed: 3.2ms preprocess, 374.8ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 1 referee, 383.2ms
# Speed: 3.1ms preprocess, 383.2ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 1 referee, 459.2ms
# Speed: 3.7ms preprocess, 459.2ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 1 referee, 409.4ms
# Speed: 3.5ms preprocess, 409.4ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 1 referee, 638.5ms
# Speed: 3.7ms preprocess, 638.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 1 referee, 541.4ms
# Speed: 3.9ms preprocess, 541.4ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 1 referee, 413.7ms
# Speed: 3.7ms preprocess, 413.7ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 1 referee, 461.2ms
# Speed: 3.6ms preprocess, 461.2ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 1 referee, 454.2ms
# Speed: 3.5ms preprocess, 454.2ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 1 referee, 382.0ms
# Speed: 3.6ms preprocess, 382.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 1 referee, 1123.3ms
# Speed: 4.5ms preprocess, 1123.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 1 referee, 658.7ms
# Speed: 3.7ms preprocess, 658.7ms inference, 5.0ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 1 referee, 780.6ms
# Speed: 4.2ms preprocess, 780.6ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 19 playerss, 1 referee, 764.1ms
# Speed: 3.8ms preprocess, 764.1ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 19 playerss, 1 referee, 800.3ms
# Speed: 3.9ms preprocess, 800.3ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 1 referee, 682.0ms
# Speed: 3.8ms preprocess, 682.0ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 801.9ms
# Speed: 4.6ms preprocess, 801.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 20 playerss, 892.8ms
# Speed: 4.1ms preprocess, 892.8ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 19 playerss, 654.1ms
# Speed: 4.0ms preprocess, 654.1ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 19 playerss, 647.7ms
# Speed: 4.0ms preprocess, 647.7ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 19 playerss, 680.6ms
# Speed: 3.5ms preprocess, 680.6ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 708.3ms
# Speed: 3.9ms preprocess, 708.3ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 428.9ms
# Speed: 3.3ms preprocess, 428.9ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 441.6ms
# Speed: 4.0ms preprocess, 441.6ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 409.2ms
# Speed: 4.9ms preprocess, 409.2ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 425.9ms
# Speed: 3.3ms preprocess, 425.9ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 409.3ms
# Speed: 3.5ms preprocess, 409.3ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 364.0ms
# Speed: 3.6ms preprocess, 364.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 1 referee, 344.5ms
# Speed: 3.2ms preprocess, 344.5ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 1 referee, 361.4ms
# Speed: 3.6ms preprocess, 361.4ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 19 playerss, 1 referee, 392.9ms
# Speed: 3.8ms preprocess, 392.9ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 1 referee, 377.8ms
# Speed: 3.1ms preprocess, 377.8ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 19 playerss, 2 referees, 361.8ms
# Speed: 3.3ms preprocess, 361.8ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 20 playerss, 2 referees, 367.8ms
# Speed: 3.5ms preprocess, 367.8ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 20 playerss, 2 referees, 361.5ms
# Speed: 3.0ms preprocess, 361.5ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 2 referees, 357.7ms
# Speed: 3.5ms preprocess, 357.7ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 349.1ms
# Speed: 3.1ms preprocess, 349.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 1 referee, 361.9ms
# Speed: 3.1ms preprocess, 361.9ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 475.5ms
# Speed: 3.6ms preprocess, 475.5ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 732.0ms
# Speed: 4.4ms preprocess, 732.0ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 1 referee, 368.8ms
# Speed: 3.2ms preprocess, 368.8ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 1 referee, 428.7ms
# Speed: 3.5ms preprocess, 428.7ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 19 playerss, 1 referee, 576.6ms
# Speed: 4.4ms preprocess, 576.6ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 2 referees, 380.9ms
# Speed: 3.4ms preprocess, 380.9ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 19 playerss, 2 referees, 382.8ms
# Speed: 3.1ms preprocess, 382.8ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 2 referees, 378.0ms
# Speed: 3.4ms preprocess, 378.0ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 2 referees, 361.4ms
# Speed: 3.2ms preprocess, 361.4ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 19 playerss, 2 referees, 356.3ms
# Speed: 3.3ms preprocess, 356.3ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 20 playerss, 2 referees, 359.8ms
# Speed: 3.2ms preprocess, 359.8ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 20 playerss, 2 referees, 423.3ms
# Speed: 3.5ms preprocess, 423.3ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 20 playerss, 1 referee, 491.3ms
# Speed: 3.9ms preprocess, 491.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 20 playerss, 404.6ms
# Speed: 3.5ms preprocess, 404.6ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 20 playerss, 2 referees, 355.6ms
# Speed: 3.3ms preprocess, 355.6ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 19 playerss, 2 referees, 434.7ms
# Speed: 3.8ms preprocess, 434.7ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 21 playerss, 2 referees, 352.4ms
# Speed: 3.3ms preprocess, 352.4ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 20 playerss, 2 referees, 339.3ms
# Speed: 3.1ms preprocess, 339.3ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 19 playerss, 2 referees, 345.4ms
# Speed: 3.3ms preprocess, 345.4ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 1 referee, 357.3ms
# Speed: 3.2ms preprocess, 357.3ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 1 referee, 368.6ms
# Speed: 3.2ms preprocess, 368.6ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 1 referee, 399.4ms
# Speed: 3.6ms preprocess, 399.4ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 1 referee, 356.9ms
# Speed: 3.0ms preprocess, 356.9ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 1 referee, 343.5ms
# Speed: 3.3ms preprocess, 343.5ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 1 referee, 341.4ms
# Speed: 3.3ms preprocess, 341.4ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 1 referee, 366.0ms
# Speed: 3.1ms preprocess, 366.0ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 1 referee, 376.9ms
# Speed: 3.5ms preprocess, 376.9ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 1 referee, 345.4ms
# Speed: 3.3ms preprocess, 345.4ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 1 referee, 379.1ms
# Speed: 3.0ms preprocess, 379.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 2 referees, 390.5ms
# Speed: 3.1ms preprocess, 390.5ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 2 referees, 374.4ms
# Speed: 3.4ms preprocess, 374.4ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 1 referee, 363.0ms
# Speed: 3.3ms preprocess, 363.0ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 2 referees, 371.3ms
# Speed: 3.0ms preprocess, 371.3ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 2 referees, 356.5ms
# Speed: 3.0ms preprocess, 356.5ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 1 referee, 351.0ms
# Speed: 3.2ms preprocess, 351.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 1 referee, 346.6ms
# Speed: 3.4ms preprocess, 346.6ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 1 referee, 356.0ms
# Speed: 3.1ms preprocess, 356.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 19 playerss, 2 referees, 408.0ms
# Speed: 3.5ms preprocess, 408.0ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 19 playerss, 2 referees, 370.7ms
# Speed: 3.3ms preprocess, 370.7ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 2 referees, 359.7ms
# Speed: 3.1ms preprocess, 359.7ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 1 referee, 655.2ms
# Speed: 4.1ms preprocess, 655.2ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 19 playerss, 1 referee, 434.1ms
# Speed: 3.5ms preprocess, 434.1ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 19 playerss, 1 referee, 1202.2ms
# Speed: 18.9ms preprocess, 1202.2ms inference, 2.2ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 1 referee, 956.6ms
# Speed: 4.3ms preprocess, 956.6ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 1 referee, 955.3ms
# Speed: 4.9ms preprocess, 955.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 1 referee, 644.9ms
# Speed: 4.3ms preprocess, 644.9ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 19 playerss, 1 referee, 421.6ms
# Speed: 3.3ms preprocess, 421.6ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 19 playerss, 2 referees, 394.1ms
# Speed: 3.5ms preprocess, 394.1ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 2 referees, 380.9ms
# Speed: 3.8ms preprocess, 380.9ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 19 playerss, 1 referee, 374.0ms
# Speed: 3.2ms preprocess, 374.0ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 21 playerss, 1 referee, 372.8ms
# Speed: 3.9ms preprocess, 372.8ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 1 referee, 388.6ms
# Speed: 3.7ms preprocess, 388.6ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 2 referees, 378.6ms
# Speed: 3.6ms preprocess, 378.6ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 2 referees, 468.8ms
# Speed: 3.2ms preprocess, 468.8ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 1 referee, 593.3ms
# Speed: 6.2ms preprocess, 593.3ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 1 referee, 1091.9ms
# Speed: 6.0ms preprocess, 1091.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 2 referees, 933.3ms
# Speed: 5.9ms preprocess, 933.3ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 2 referees, 1101.5ms
# Speed: 4.0ms preprocess, 1101.5ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 2 referees, 471.1ms
# Speed: 3.8ms preprocess, 471.1ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 2 referees, 2131.2ms
# Speed: 153.7ms preprocess, 2131.2ms inference, 1.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 1 referee, 1117.2ms
# Speed: 5.6ms preprocess, 1117.2ms inference, 1.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 19 playerss, 1 referee, 894.4ms
# Speed: 5.1ms preprocess, 894.4ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 1 referee, 1047.8ms
# Speed: 7.3ms preprocess, 1047.8ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 1 referee, 1115.0ms
# Speed: 4.0ms preprocess, 1115.0ms inference, 1.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 796.3ms
# Speed: 10.2ms preprocess, 796.3ms inference, 24.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 2400.9ms
# Speed: 6.1ms preprocess, 2400.9ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 1996.0ms
# Speed: 19.8ms preprocess, 1996.0ms inference, 2.2ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 1 referee, 1141.5ms
# Speed: 6.7ms preprocess, 1141.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 1 referee, 648.9ms
# Speed: 4.3ms preprocess, 648.9ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 2 referees, 680.4ms
# Speed: 3.8ms preprocess, 680.4ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 2 referees, 500.4ms
# Speed: 4.0ms preprocess, 500.4ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 1 referee, 666.8ms
# Speed: 3.8ms preprocess, 666.8ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 1 referee, 1068.9ms
# Speed: 4.4ms preprocess, 1068.9ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 1 referee, 649.1ms
# Speed: 3.7ms preprocess, 649.1ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 1 referee, 393.3ms
# Speed: 4.7ms preprocess, 393.3ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 2 referees, 395.4ms
# Speed: 3.9ms preprocess, 395.4ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 2 referees, 391.2ms
# Speed: 3.2ms preprocess, 391.2ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 20 playerss, 2 referees, 438.3ms
# Speed: 3.8ms preprocess, 438.3ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 20 playerss, 2 referees, 431.8ms
# Speed: 4.0ms preprocess, 431.8ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 19 playerss, 1 referee, 466.6ms
# Speed: 6.8ms preprocess, 466.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 2 referees, 475.9ms
# Speed: 3.5ms preprocess, 475.9ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 2 referees, 424.2ms
# Speed: 3.4ms preprocess, 424.2ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 2 referees, 379.6ms
# Speed: 3.4ms preprocess, 379.6ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 2 referees, 434.1ms
# Speed: 3.4ms preprocess, 434.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 2 referees, 418.2ms
# Speed: 3.7ms preprocess, 418.2ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 1 referee, 379.4ms
# Speed: 3.1ms preprocess, 379.4ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 19 playerss, 1 referee, 372.3ms
# Speed: 3.4ms preprocess, 372.3ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 19 playerss, 1 referee, 374.4ms
# Speed: 3.3ms preprocess, 374.4ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 2 referees, 366.7ms
# Speed: 3.1ms preprocess, 366.7ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 2 referees, 365.8ms
# Speed: 3.4ms preprocess, 365.8ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 1 referee, 379.3ms
# Speed: 3.5ms preprocess, 379.3ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 1 referee, 373.4ms
# Speed: 3.4ms preprocess, 373.4ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 2 referees, 358.5ms
# Speed: 3.1ms preprocess, 358.5ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 2 referees, 353.2ms
# Speed: 3.0ms preprocess, 353.2ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 2 referees, 400.2ms
# Speed: 3.2ms preprocess, 400.2ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 2 referees, 543.5ms
# Speed: 3.9ms preprocess, 543.5ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 2 referees, 377.4ms
# Speed: 3.3ms preprocess, 377.4ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 2 referees, 365.8ms
# Speed: 3.5ms preprocess, 365.8ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 1 referee, 555.6ms
# Speed: 36.3ms preprocess, 555.6ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 1 referee, 390.0ms
# Speed: 3.2ms preprocess, 390.0ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 1 referee, 389.4ms
# Speed: 3.6ms preprocess, 389.4ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 2 referees, 416.2ms
# Speed: 3.6ms preprocess, 416.2ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 2 referees, 409.8ms
# Speed: 3.7ms preprocess, 409.8ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 20 playerss, 2 referees, 614.1ms
# Speed: 4.1ms preprocess, 614.1ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 19 playerss, 1 referee, 929.0ms
# Speed: 3.8ms preprocess, 929.0ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 20 playerss, 2 referees, 928.7ms
# Speed: 5.1ms preprocess, 928.7ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 2 referees, 693.7ms
# Speed: 3.8ms preprocess, 693.7ms inference, 1.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 2 referees, 389.1ms
# Speed: 3.3ms preprocess, 389.1ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 2 referees, 429.9ms
# Speed: 4.3ms preprocess, 429.9ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 2 referees, 627.9ms
# Speed: 4.0ms preprocess, 627.9ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 1 referee, 345.3ms
# Speed: 3.4ms preprocess, 345.3ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 1 referee, 380.7ms
# Speed: 3.5ms preprocess, 380.7ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 1 referee, 504.4ms
# Speed: 3.8ms preprocess, 504.4ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 1 referee, 430.4ms
# Speed: 5.4ms preprocess, 430.4ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 1 referee, 360.3ms
# Speed: 3.4ms preprocess, 360.3ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 2 referees, 407.1ms
# Speed: 3.4ms preprocess, 407.1ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 2 referees, 486.2ms
# Speed: 3.5ms preprocess, 486.2ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 1 referee, 1338.0ms
# Speed: 3.5ms preprocess, 1338.0ms inference, 2.2ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 2 referees, 471.2ms
# Speed: 4.3ms preprocess, 471.2ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 2 referees, 504.9ms
# Speed: 3.6ms preprocess, 504.9ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 2 referees, 433.9ms
# Speed: 3.6ms preprocess, 433.9ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 2 referees, 433.1ms
# Speed: 3.8ms preprocess, 433.1ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 19 playerss, 2 referees, 457.7ms
# Speed: 3.6ms preprocess, 457.7ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 19 playerss, 2 referees, 381.1ms
# Speed: 3.6ms preprocess, 381.1ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 2 referees, 348.4ms
# Speed: 3.4ms preprocess, 348.4ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 19 playerss, 1 referee, 367.3ms
# Speed: 3.5ms preprocess, 367.3ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 1 referee, 366.2ms
# Speed: 3.2ms preprocess, 366.2ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 2 referees, 466.3ms
# Speed: 3.2ms preprocess, 466.3ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 2 referees, 375.7ms
# Speed: 3.1ms preprocess, 375.7ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 2 referees, 348.5ms
# Speed: 3.1ms preprocess, 348.5ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 2 referees, 378.1ms
# Speed: 3.1ms preprocess, 378.1ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 2 referees, 403.0ms
# Speed: 3.7ms preprocess, 403.0ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 2 referees, 368.5ms
# Speed: 3.3ms preprocess, 368.5ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 2 referees, 398.2ms
# Speed: 3.5ms preprocess, 398.2ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 2 referees, 741.0ms
# Speed: 7.1ms preprocess, 741.0ms inference, 1.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 2 referees, 544.1ms
# Speed: 4.8ms preprocess, 544.1ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 2 referees, 446.3ms
# Speed: 3.4ms preprocess, 446.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 2 referees, 434.1ms
# Speed: 3.8ms preprocess, 434.1ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 1 referee, 630.8ms
# Speed: 5.3ms preprocess, 630.8ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 1 referee, 432.8ms
# Speed: 3.7ms preprocess, 432.8ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 1 referee, 393.7ms
# Speed: 3.2ms preprocess, 393.7ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 1 referee, 476.6ms
# Speed: 3.7ms preprocess, 476.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 1 referee, 407.0ms
# Speed: 3.4ms preprocess, 407.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 2 referees, 370.0ms
# Speed: 3.4ms preprocess, 370.0ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 2 referees, 447.4ms
# Speed: 4.1ms preprocess, 447.4ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 2 referees, 464.3ms
# Speed: 3.5ms preprocess, 464.3ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 1 referee, 626.2ms
# Speed: 26.6ms preprocess, 626.2ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 1 referee, 352.8ms
# Speed: 3.3ms preprocess, 352.8ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 1 referee, 445.7ms
# Speed: 3.2ms preprocess, 445.7ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 1 referee, 409.0ms
# Speed: 3.8ms preprocess, 409.0ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 2 referees, 683.9ms
# Speed: 4.1ms preprocess, 683.9ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 1 referee, 444.8ms
# Speed: 3.5ms preprocess, 444.8ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 1 referee, 450.8ms
# Speed: 3.4ms preprocess, 450.8ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 3 referees, 430.5ms
# Speed: 3.2ms preprocess, 430.5ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 3 referees, 546.4ms
# Speed: 3.3ms preprocess, 546.4ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 2 referees, 716.7ms
# Speed: 3.6ms preprocess, 716.7ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 3 referees, 599.7ms
# Speed: 4.0ms preprocess, 599.7ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 2 referees, 479.8ms
# Speed: 4.6ms preprocess, 479.8ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 2 referees, 441.5ms
# Speed: 3.7ms preprocess, 441.5ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 2 referees, 371.6ms
# Speed: 3.1ms preprocess, 371.6ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 3 referees, 366.9ms
# Speed: 3.1ms preprocess, 366.9ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 3 referees, 371.8ms
# Speed: 3.1ms preprocess, 371.8ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 3 referees, 658.6ms
# Speed: 4.2ms preprocess, 658.6ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 3 referees, 382.1ms
# Speed: 3.7ms preprocess, 382.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 2 referees, 751.8ms
# Speed: 3.2ms preprocess, 751.8ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 2 referees, 479.4ms
# Speed: 4.0ms preprocess, 479.4ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 3 referees, 663.3ms
# Speed: 3.9ms preprocess, 663.3ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 2 referees, 808.0ms
# Speed: 3.2ms preprocess, 808.0ms inference, 1.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 2 referees, 401.3ms
# Speed: 4.2ms preprocess, 401.3ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 2 referees, 520.1ms
# Speed: 5.0ms preprocess, 520.1ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 2 referees, 469.3ms
# Speed: 3.6ms preprocess, 469.3ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 2 referees, 391.2ms
# Speed: 4.0ms preprocess, 391.2ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 1 referee, 362.2ms
# Speed: 3.5ms preprocess, 362.2ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 1 referee, 749.5ms
# Speed: 132.4ms preprocess, 749.5ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 1 referee, 970.9ms
# Speed: 4.1ms preprocess, 970.9ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 1 referee, 773.4ms
# Speed: 3.9ms preprocess, 773.4ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 1 referee, 407.9ms
# Speed: 3.9ms preprocess, 407.9ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 2 referees, 604.9ms
# Speed: 4.4ms preprocess, 604.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 2 referees, 663.4ms
# Speed: 3.8ms preprocess, 663.4ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 2 referees, 646.3ms
# Speed: 3.5ms preprocess, 646.3ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 2 referees, 919.6ms
# Speed: 3.6ms preprocess, 919.6ms inference, 1.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 2 referees, 407.5ms
# Speed: 3.7ms preprocess, 407.5ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 2 referees, 386.0ms
# Speed: 3.9ms preprocess, 386.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 1 referee, 480.1ms
# Speed: 3.9ms preprocess, 480.1ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 19 playerss, 2 referees, 487.0ms
# Speed: 3.9ms preprocess, 487.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 2 referees, 416.8ms
# Speed: 3.8ms preprocess, 416.8ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 2 referees, 392.6ms
# Speed: 3.5ms preprocess, 392.6ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 2 referees, 403.9ms
# Speed: 3.8ms preprocess, 403.9ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 1 referee, 1032.7ms
# Speed: 3.6ms preprocess, 1032.7ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 1 referee, 368.1ms
# Speed: 3.4ms preprocess, 368.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 12 playerss, 1 referee, 492.5ms
# Speed: 3.8ms preprocess, 492.5ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 1 referee, 576.3ms
# Speed: 4.6ms preprocess, 576.3ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 2 referees, 390.7ms
# Speed: 3.7ms preprocess, 390.7ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 2 referees, 657.8ms
# Speed: 3.9ms preprocess, 657.8ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 2 referees, 788.1ms
# Speed: 3.2ms preprocess, 788.1ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 2 referees, 461.1ms
# Speed: 3.5ms preprocess, 461.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 2 referees, 792.3ms
# Speed: 3.5ms preprocess, 792.3ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 1 referee, 713.9ms
# Speed: 3.6ms preprocess, 713.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 2 referees, 767.0ms
# Speed: 4.4ms preprocess, 767.0ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 2 referees, 432.9ms
# Speed: 3.1ms preprocess, 432.9ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 2 referees, 545.2ms
# Speed: 3.6ms preprocess, 545.2ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 2 referees, 444.3ms
# Speed: 3.4ms preprocess, 444.3ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 2 referees, 879.7ms
# Speed: 4.1ms preprocess, 879.7ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 1 referee, 601.2ms
# Speed: 5.3ms preprocess, 601.2ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 1 referee, 741.3ms
# Speed: 3.6ms preprocess, 741.3ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 1 referee, 661.9ms
# Speed: 4.3ms preprocess, 661.9ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 18 playerss, 2 referees, 380.9ms
# Speed: 3.5ms preprocess, 380.9ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 2 referees, 810.3ms
# Speed: 3.7ms preprocess, 810.3ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 2 referees, 508.3ms
# Speed: 4.0ms preprocess, 508.3ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 2 referees, 417.5ms
# Speed: 3.3ms preprocess, 417.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 1 referee, 543.5ms
# Speed: 3.6ms preprocess, 543.5ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 1 referee, 381.6ms
# Speed: 3.5ms preprocess, 381.6ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 1 referee, 376.0ms
# Speed: 3.1ms preprocess, 376.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 1 referee, 371.7ms
# Speed: 3.1ms preprocess, 371.7ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 2 referees, 789.9ms
# Speed: 3.1ms preprocess, 789.9ms inference, 1.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 2 referees, 488.0ms
# Speed: 3.5ms preprocess, 488.0ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 2 referees, 420.2ms
# Speed: 3.8ms preprocess, 420.2ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 2 referees, 424.4ms
# ...
#
# 0: 544x800 17 playerss, 3 referees, 391.3ms
# Speed: 3.4ms preprocess, 391.3ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 2 referees, 447.1ms
# Speed: 4.9ms preprocess, 447.1ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 3 referees, 472.9ms
# Speed: 3.9ms preprocess, 472.9ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 17 playerss, 3 referees, 397.7ms
# Speed: 3.4ms preprocess, 397.7ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 16 playerss, 2 referees, 493.7ms
# Speed: 4.7ms preprocess, 493.7ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 2 referees, 397.6ms
# Speed: 3.4ms preprocess, 397.6ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 1 referee, 382.7ms
# Speed: 3.4ms preprocess, 382.7ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 1 referee, 505.8ms
# Speed: 3.4ms preprocess, 505.8ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 1 referee, 378.3ms
# Speed: 3.4ms preprocess, 378.3ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 1 referee, 447.6ms
# Speed: 3.7ms preprocess, 447.6ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 2 referees, 510.1ms
# Speed: 3.6ms preprocess, 510.1ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 3 referees, 384.7ms
# Speed: 3.4ms preprocess, 384.7ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 3 referees, 383.4ms
# Speed: 3.2ms preprocess, 383.4ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 3 referees, 425.2ms
# Speed: 3.3ms preprocess, 425.2ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 3 referees, 400.3ms
# Speed: 3.1ms preprocess, 400.3ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 3 referees, 453.9ms
# Speed: 3.8ms preprocess, 453.9ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 3 referees, 402.4ms
# Speed: 3.4ms preprocess, 402.4ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 3 referees, 477.8ms
# Speed: 3.8ms preprocess, 477.8ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 3 referees, 452.0ms
# Speed: 3.8ms preprocess, 452.0ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 3 referees, 468.0ms
# Speed: 4.0ms preprocess, 468.0ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 2 referees, 390.7ms
# Speed: 3.3ms preprocess, 390.7ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 2 referees, 500.1ms
# Speed: 3.6ms preprocess, 500.1ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 2 referees, 444.4ms
# Speed: 3.8ms preprocess, 444.4ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 2 referees, 405.3ms
# Speed: 3.5ms preprocess, 405.3ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 2 referees, 399.8ms
# Speed: 3.5ms preprocess, 399.8ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 2 referees, 470.8ms
# Speed: 3.6ms preprocess, 470.8ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 2 referees, 489.0ms
# Speed: 3.8ms preprocess, 489.0ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 2 referees, 418.6ms
# Speed: 3.5ms preprocess, 418.6ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 2 referees, 725.8ms
# Speed: 3.8ms preprocess, 725.8ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 2 referees, 493.4ms
# Speed: 3.4ms preprocess, 493.4ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 2 referees, 422.8ms
# Speed: 3.3ms preprocess, 422.8ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 2 referees, 473.6ms
# Speed: 3.9ms preprocess, 473.6ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 2 referees, 521.9ms
# Speed: 4.5ms preprocess, 521.9ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 2 referees, 405.4ms
# Speed: 3.8ms preprocess, 405.4ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 2 referees, 542.6ms
# Speed: 3.8ms preprocess, 542.6ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 2 referees, 422.3ms
# Speed: 9.0ms preprocess, 422.3ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 10 playerss, 2 referees, 381.3ms
# Speed: 3.4ms preprocess, 381.3ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 12 playerss, 3 referees, 456.5ms
# Speed: 4.0ms preprocess, 456.5ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 2 referees, 747.9ms
# Speed: 4.0ms preprocess, 747.9ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 2 referees, 457.7ms
# Speed: 3.7ms preprocess, 457.7ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 12 playerss, 3 referees, 450.9ms
# Speed: 3.8ms preprocess, 450.9ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 3 referees, 438.8ms
# Speed: 3.8ms preprocess, 438.8ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 12 playerss, 3 referees, 416.4ms
# Speed: 3.8ms preprocess, 416.4ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 12 playerss, 2 referees, 403.2ms
# Speed: 4.0ms preprocess, 403.2ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 11 playerss, 2 referees, 464.1ms
# Speed: 3.8ms preprocess, 464.1ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 11 playerss, 2 referees, 500.9ms
# Speed: 3.6ms preprocess, 500.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 11 playerss, 2 referees, 406.9ms
# Speed: 3.9ms preprocess, 406.9ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 12 playerss, 2 referees, 373.2ms
# Speed: 3.4ms preprocess, 373.2ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 12 playerss, 2 referees, 591.6ms
# Speed: 4.8ms preprocess, 591.6ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 12 playerss, 2 referees, 384.7ms
# Speed: 3.6ms preprocess, 384.7ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 10 playerss, 2 referees, 424.4ms
# Speed: 3.3ms preprocess, 424.4ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 11 playerss, 2 referees, 443.9ms
# Speed: 3.8ms preprocess, 443.9ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 10 playerss, 3 referees, 415.9ms
# Speed: 3.8ms preprocess, 415.9ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 12 playerss, 3 referees, 392.8ms
# Speed: 3.7ms preprocess, 392.8ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 9 playerss, 3 referees, 404.2ms
# Speed: 3.3ms preprocess, 404.2ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 8 playerss, 3 referees, 442.7ms
# Speed: 3.7ms preprocess, 442.7ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 8 playerss, 3 referees, 409.1ms
# Speed: 3.6ms preprocess, 409.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 9 playerss, 2 referees, 435.3ms
# Speed: 3.7ms preprocess, 435.3ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 10 playerss, 2 referees, 422.1ms
# Speed: 3.7ms preprocess, 422.1ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 10 playerss, 2 referees, 408.9ms
# Speed: 3.9ms preprocess, 408.9ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 11 playerss, 2 referees, 410.9ms
# Speed: 3.7ms preprocess, 410.9ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 12 playerss, 2 referees, 410.2ms
# Speed: 3.8ms preprocess, 410.2ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 12 playerss, 2 referees, 558.0ms
# Speed: 5.6ms preprocess, 558.0ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 12 playerss, 2 referees, 403.7ms
# Speed: 3.9ms preprocess, 403.7ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 2 referees, 400.5ms
# Speed: 4.1ms preprocess, 400.5ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 2 referees, 462.5ms
# Speed: 3.5ms preprocess, 462.5ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 2 referees, 466.5ms
# Speed: 4.5ms preprocess, 466.5ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 2 referees, 685.9ms
# Speed: 3.7ms preprocess, 685.9ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 2 referees, 378.4ms
# Speed: 3.4ms preprocess, 378.4ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 3 referees, 447.2ms
# Speed: 3.4ms preprocess, 447.2ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 2 referees, 396.0ms
# Speed: 3.3ms preprocess, 396.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 2 referees, 392.8ms
# Speed: 3.4ms preprocess, 392.8ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 3 referees, 560.8ms
# Speed: 3.6ms preprocess, 560.8ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 12 playerss, 2 referees, 392.8ms
# Speed: 3.4ms preprocess, 392.8ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 12 playerss, 2 referees, 560.8ms
# Speed: 3.8ms preprocess, 560.8ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 12 playerss, 2 referees, 534.7ms
# Speed: 5.3ms preprocess, 534.7ms inference, 1.5ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 12 playerss, 2 referees, 395.8ms
# Speed: 3.2ms preprocess, 395.8ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 11 playerss, 2 referees, 395.6ms
# Speed: 3.4ms preprocess, 395.6ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 10 playerss, 2 referees, 423.6ms
# Speed: 4.0ms preprocess, 423.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 12 playerss, 2 referees, 433.1ms
# Speed: 4.0ms preprocess, 433.1ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 11 playerss, 2 referees, 541.7ms
# Speed: 3.7ms preprocess, 541.7ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 10 playerss, 2 referees, 487.1ms
# Speed: 3.7ms preprocess, 487.1ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 2 referees, 400.1ms
# Speed: 4.0ms preprocess, 400.1ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 11 playerss, 2 referees, 703.6ms
# Speed: 3.2ms preprocess, 703.6ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 12 playerss, 2 referees, 399.5ms
# Speed: 3.3ms preprocess, 399.5ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 10 playerss, 2 referees, 413.7ms
# Speed: 3.7ms preprocess, 413.7ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 10 playerss, 2 referees, 493.9ms
# Speed: 4.0ms preprocess, 493.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 9 playerss, 2 referees, 470.3ms
# Speed: 3.9ms preprocess, 470.3ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 9 playerss, 2 referees, 441.4ms
# Speed: 3.7ms preprocess, 441.4ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 10 playerss, 2 referees, 1165.8ms
# Speed: 3.3ms preprocess, 1165.8ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 12 playerss, 2 referees, 521.4ms
# Speed: 3.9ms preprocess, 521.4ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 2 referees, 501.7ms
# Speed: 3.9ms preprocess, 501.7ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 3 referees, 466.5ms
# Speed: 3.8ms preprocess, 466.5ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 3 referees, 483.8ms
# Speed: 3.7ms preprocess, 483.8ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 2 referees, 604.7ms
# Speed: 4.5ms preprocess, 604.7ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 4 referees, 419.3ms
# Speed: 3.8ms preprocess, 419.3ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 12 playerss, 2 referees, 533.6ms
# Speed: 4.0ms preprocess, 533.6ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 2 referees, 436.3ms
# Speed: 3.8ms preprocess, 436.3ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 2 referees, 596.2ms
# Speed: 5.7ms preprocess, 596.2ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 2 referees, 413.8ms
# Speed: 3.2ms preprocess, 413.8ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 2 referees, 423.2ms
# Speed: 3.5ms preprocess, 423.2ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 2 referees, 484.7ms
# Speed: 3.5ms preprocess, 484.7ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 2 referees, 568.0ms
# Speed: 9.9ms preprocess, 568.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 2 referees, 419.0ms
# Speed: 3.2ms preprocess, 419.0ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 12 playerss, 2 referees, 630.2ms
# Speed: 4.3ms preprocess, 630.2ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 11 playerss, 2 referees, 416.2ms
# Speed: 3.4ms preprocess, 416.2ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 13 playerss, 2 referees, 506.5ms
# Speed: 3.7ms preprocess, 506.5ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 14 playerss, 2 referees, 433.2ms
# Speed: 4.1ms preprocess, 433.2ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 15 playerss, 2 referees, 798.6ms
# Speed: 3.9ms preprocess, 798.6ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 800)
# Failed to read frame or end of video reached.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# change

# Aggregate labels 0 to 3, safely handling missing labels
total_0_to_3 = sum(class_detection_counts.get(label, 0) for label in range(4))  # Use .get with default value 0
average_detections_per_class = {'0-3': total_0_to_3 / frame_nbr}  # Compute average for aggregated labels

# Compute average for label 4, safely handling cases where label might not be present
average_detections_per_class['4'] = class_detection_counts.get(4, 0) / frame_nbr

print("Average number of detections per class per frame:", average_detections_per_class)

# print("Average number of detections per class per frame:", 
#       class_detection_counts[0]/frame_nbr, 
#       class_detection_counts[1]/frame_nbr, 
      
#       )
# Out:
# Average number of detections per class per frame: {'0-3': 16.78044871794872, '4': 0.08333333333333333}

# %%
class_detection_counts[2]/frame_nbr
# Out:
# 0.0018331805682859762
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import cv2
import os
import numpy as np

def create_video_from_frames(frame_folder, output_video_path, fps=30, codec='XVID'):
    # Define the codec and create VideoWriter object
    fourcc = cv2.VideoWriter_fourcc(*codec)
    frame_files = sorted([os.path.join(frame_folder, f) for f in os.listdir(frame_folder) if f.endswith('.jpg')])
    
    # Read the first frame to get the size
    first_frame = cv2.imread(frame_files[0])
    height, width, layers = first_frame.shape
    video = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

    for frame_file in frame_files:
        frame = cv2.imread(frame_file)
        video.write(frame)
    
    video.release()

# Usage
frame_folder = 'saved_frames'  # Folder containing all the frames
output_video_path = 'output_video.avi'  # Path where the output video will be saved
fps = 20  # Frames per second of the output video

create_video_from_frames(frame_folder, output_video_path, fps)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
print(cv2.__version__) #4.5.5.64
# Out:
# 4.5.5

# %%
# !pip install --upgrade opencv-python
# Out:
# Requirement already satisfied: opencv-python in /Users/othmaneechchabi/anaconda3/lib/python3.10/site-packages (4.5.5.64)
# Collecting opencv-python
#   Using cached opencv_python-4.9.0.80-cp37-abi3-macosx_11_0_arm64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in /Users/othmaneechchabi/anaconda3/lib/python3.10/site-packages (from opencv-python) (1.24.3)
# Using cached opencv_python-4.9.0.80-cp37-abi3-macosx_11_0_arm64.whl (35.4 MB)
# Installing collected packages: opencv-python
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.5.5.64
#     Uninstalling opencv-python-4.5.5.64:
#       Successfully uninstalled opencv-python-4.5.5.64
# Successfully installed opencv-python-4.9.0.80

# %%
# !pip install opencv-python==4.5.5.64
# Out:
# Collecting opencv-python==4.5.5.64
#   Using cached opencv_python-4.5.5.64-cp37-abi3-macosx_11_0_arm64.whl.metadata (18 kB)
# Requirement already satisfied: numpy>=1.21.2 in /Users/othmaneechchabi/anaconda3/lib/python3.10/site-packages (from opencv-python==4.5.5.64) (1.24.3)
# Using cached opencv_python-4.5.5.64-cp37-abi3-macosx_11_0_arm64.whl (29.9 MB)
# Installing collected packages: opencv-python
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.9.0.80
#     Uninstalling opencv-python-4.9.0.80:
#       Successfully uninstalled opencv-python-4.9.0.80
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ultralytics 8.2.2 requires opencv-python>=4.6.0, but you have opencv-python 4.5.5.64 which is incompatible.
# Successfully installed opencv-python-4.5.5.64
