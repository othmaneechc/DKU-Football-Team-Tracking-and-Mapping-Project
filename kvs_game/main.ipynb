# %%
# Import libraries
import numpy as np
import pandas as pd
import os 
import cv2
import skimage
from PIL import Image
from ultralytics import YOLO
from matplotlib import pyplot as plt
import json
import time

# %% [markdown]
# ## Calculating Homography Matrix using keypoints coordinates

# %%
# Load the original image to get its dimensions
# change
# original_image = cv2.imread('kvs.png')
original_image = cv2.imread('trainingw.jpg')
original_height, original_width = original_image.shape[:2]

# New dimensions to which the frame is resized
# window_width = 854
# window_height = 480

# change
# keypoints_path = "vocational_keypoints.json"
keypoints_path = "trainingW.json"

window_width = original_width
window_height = original_height
print(window_width, window_height)

# Calculate scaling factors
x_scale = window_width / original_width
y_scale = window_height / original_height

# Load coordinates from JSON file
with open(f'coordinates/{keypoints_path}', 'r') as f:
    vocational_keypoints = json.load(f)

# Update coordinates with the scaling factor
for key, value in vocational_keypoints.items():
    if value:  # Check if the list is not empty
        x, y = value
        new_x = int(x * x_scale)
        new_y = int(y * y_scale)
        vocational_keypoints[key] = [new_x, new_y]

# Optionally, save the updated coordinates back to a file
with open('coordinates/updated.json', 'w') as f:
    json.dump(vocational_keypoints, f, indent=2)

with open('coordinates/updated.json', 'r') as f:
    vocational_keypoints = json.load(f)

with open('coordinates/map_keypoints.json', 'r') as f:
    map_keypoints = json.load(f)

# Filter out keypoints that are not visible
image_points = []
map_points = []
label_points = {}

i = 0

for key in vocational_keypoints:
    if vocational_keypoints[key] and map_keypoints[key]:  # Ensure keypoints are visible on both the frame and the map
        image_points.append(vocational_keypoints[key])
        map_points.append(map_keypoints[key])
        label_points[key] = i 
        i+=1

# Convert to NumPy arrays
image_points = np.array(image_points, dtype=np.float32)
map_points = np.array(map_points, dtype=np.float32)

# Calculate the homography matrix
H, status = cv2.findHomography(image_points, map_points, cv2.RANSAC, 5.0)
H
# Out:
# 1920 1080
# array([[   0.061859,     0.13731,      -336.4],
#        [   -0.10681,    -0.99878,      343.24],
#        [ 5.3823e-05,  -0.0028022,           1]])

# %% [markdown]
# ## Loading weights and setting labels depending on the model

# %%
# import torch

# # Load the YOLO model
# model = torch.load('weights/best_nafie.pt', map_location=torch.device('cpu'))
# print(model)

# %%
# Load the YOLOv8 players detection model
# change

# weight = "weights/best.pt"
# labels_dic = {
#     0:"player",
#     1:"referee",
#     2:"ball",
# }

weight = "weights/best_nafie.pt"
labels_dic = {
    0:"Player team left",
    1:"Player team right",
    2:"Goalkeeper team left",
    3:"Goalkeeper team right",
    4:"Ball",
    5:"Main referee",
    6:"Side referee",
    7:"Staff members",
}

model_players = YOLO(weight)

# %% [markdown]
# ## Set Parameters

# %%
# Initialize frame counter
frame_nbr = 0

# Set confidence thresholds for players and field keypoints detections
player_model_conf_thresh = 0.50

# Set variable to record the time when we processed last frame 
prev_frame_time = 0
# Set variable to record the time at which we processed current frame 
new_frame_time = 0

# Store the ball track history
ball_track_history = {'src':[],
                      'dst':[]
}

# Count consecutive frames with no ball detected
nbr_frames_no_ball = 0
# Threshold for number of frames with no ball to reset ball track (frames)
nbr_frames_no_ball_thresh = 30
# Distance threshold for ball tracking (pixels)
ball_track_dist_thresh = 100
# Maximum ball track length (detections)
max_track_length = 35

# Initialize counters and storage for class detections
class_detection_counts = {}

# %% [markdown]
# ## Choosing video and finding team colors

# %%
# change

# video_path = './videos/KVS_H1_TEST.mp4'
video_path = './videos/TrainingW_TEST.mp4'

tac_map = cv2.imread('./map.jpg')

# %% [markdown]
# #### K-means clustering

# %%
img = original_image
hsv = cv2.cvtColor(original_image, cv2.COLOR_BGR2HSV)

# Define a large range of green color in HSV
lower_green = np.array([30, 40, 40])
upper_green = np.array([80, 255, 255])

# Threshold the HSV image to get only green colors
mask = cv2.inRange(hsv, lower_green, upper_green)

# Calculate the mean value of the pixels that are not masked
masked_img = cv2.bitwise_and(img, img, mask=mask)
plt.imshow(masked_img)
grass_color = cv2.mean(img, mask=mask)
grass_color = grass_color[:3]
print("Grass BGR color: ", grass_color)
# Out:
# Grass BGR color:  (51.87859444151829, 105.67783926507104, 70.92713504935324)

# %%
# Perform detection
results_players = model_players(img, conf=player_model_conf_thresh)

# Extract detection data
bboxes_p = results_players[0].boxes.xyxy.cpu().numpy() 
labels_p = list(results_players[0].boxes.cls.cpu().numpy())
confs_p = list(results_players[0].boxes.conf.cpu().numpy())

kits_colors = []
grass_hsv = cv2.cvtColor(np.uint8([[list(grass_color)]]), cv2.COLOR_BGR2HSV)

# Process each detection
for i, label in enumerate(labels_p):
    if label == 0:  # Assuming '0' is the label for players
        x1, y1, x2, y2 = map(int, bboxes_p[i])
        player_img = img[y1:y2, x1:x2]
        hsv = cv2.cvtColor(player_img, cv2.COLOR_BGR2HSV)

        # Adjust the green range based on the average grass color
        lower_green = np.array([grass_hsv[0, 0, 0] - 10, 40, 40])
        upper_green = np.array([grass_hsv[0, 0, 0] + 10, 255, 255])
        mask = cv2.inRange(hsv, lower_green, upper_green)
        mask = cv2.bitwise_not(mask)

        # Apply a mask to get the upper half of the player (typically where the kit is most visible)
        upper_mask = np.zeros(player_img.shape[:2], np.uint8)
        upper_mask[0:player_img.shape[0]//2, :] = 255
        mask = cv2.bitwise_and(mask, upper_mask)
        masked_img = cv2.bitwise_and(player_img, player_img, mask=mask)

        # Calculate the mean color of the player's kit
        player_kit_color = np.array(cv2.mean(player_img, mask=mask)[:3])
        kits_colors.append(player_kit_color)

        # Display results
        plt.imshow(cv2.cvtColor(masked_img, cv2.COLOR_BGR2RGB))
        plt.title(f"Player Kit Color: {player_kit_color}")
        plt.show()
# Out:
# 0: 416x736 20 Players, 251.6ms
# Speed: 2.5ms preprocess, 251.6ms inference, 327.2ms postprocess per image at shape (1, 3, 416, 736)

# %%
import numpy as np
from sklearn.cluster import KMeans
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")

# Assuming kits_colors contains the BGR colors of the player kits extracted previously
kits_colors = np.array(kits_colors)

# Apply K-means clustering to classify the kits into two distinct colors
kits_kmeans = KMeans(n_clusters=2)
kits_kmeans.fit(kits_colors)

# Convert the BGR color format to RGB for visualization
kits_colors_rgb = kits_colors[:, [2, 1, 0]]  # Reversing BGR to RGB
cluster_centers_rgb = kits_kmeans.cluster_centers_[:, [2, 1, 0]]

# Create a 3D scatter plot of the kit colors
fig = px.scatter_3d(
    x=kits_colors_rgb[:, 0],
    y=kits_colors_rgb[:, 1],
    z=kits_colors_rgb[:, 2],
    range_x=[0, 255],
    range_y=[0, 255],
    range_z=[0, 255],
    title="Kits Colors Clustering",
    color=kits_kmeans.labels_
)

# Add the cluster centers to the plot
fig.add_scatter3d(
    x=cluster_centers_rgb[:, 0],
    y=cluster_centers_rgb[:, 1],
    z=cluster_centers_rgb[:, 2],
    mode='markers',
    marker=dict(color='black', size=10, symbol='cross'),
    name='Cluster Centers'
)

fig.show()

# %%
# change
Team1 = "Team1"
Team2 = "Team2"

colors_dic = {
    f"{Team1}": [tuple(map(int, cluster_centers_rgb[0]))],  # Convert the first centroid to integer values
    f"{Team2}": [tuple(map(int, cluster_centers_rgb[1]))]   # Convert the second centroid to integer values
}

# Define team colors
nbr_team_colors = 1

# %%
colors_dic
# Out:
# {'Team1': [(152, 152, 110)], 'Team2': [(92, 96, 84)]}

# %% [markdown]
# #### Manual method

# %%
# change

# colors_dic = {
#     "Purple":[(105,105,160), (105,105,160)], # DKU Colors (Players kit color, GK kit color)
#     "Yellow":[(200,200,100), (200,200,100)] # KVS Colors (Players kit color, GK kit color)
# }
# colors_list = colors_dic["Purple"]+colors_dic["Yellow"] # Define color list to be used for detected player team prediction

# colors_dic = {
#     "DKU":[(200,200,200), (115,144,98)], # DKU Colors (Players kit color, GK kit color)
#     "KVS":[(120,52,47), (47,103,43)] # KVS Colors (Players kit color, GK kit color)
# }

# %%
colors_list = colors_dic[f"{Team1}"]+colors_dic[f"{Team2}"] # Define color list to be used for detected player team prediction
color_list_lab = [skimage.color.rgb2lab([i/255 for i in c]) for c in colors_list] # Converting color_list to L*a*b* space

# %% [markdown]
# ## Running the model

# %%
frame_save_path = 'saved_frames'
os.makedirs(frame_save_path, exist_ok=True)  # Create the directory if it doesn't exist

# Open video file
cap = cv2.VideoCapture(video_path)

# Loop through the video frames
while cap.isOpened():

    # Read a frame from the video
    success, frame = cap.read()
    if not success:
        print("Failed to read frame or end of video reached.")
        break  # Exit the loop if no frame is read or end of video is reached

    frame = cv2.resize(frame, (window_width, window_height))

    # Save each frame to the folder
    frame_nbr += 1
    
    # Save number of detections per frame
    current_frame_class_counts = {}

    # Reset tactical map image for each new frame
    tac_map_copy = tac_map.copy()
    # Define the transparency factor (alpha)
    alpha = 0.5  # 50% transparency
    beta = (1.0 - alpha)  # Weight of the second array elements

    # Create a black background of the same size as the tactical map
    background = np.zeros_like(tac_map_copy)

    # Blend the tactical map with the black background
    tac_map_copy = cv2.addWeighted(tac_map_copy, alpha, background, beta, 0)

    # Reset ball tracks
    if nbr_frames_no_ball>nbr_frames_no_ball_thresh:
            ball_track_history['dst'] = []
            ball_track_history['src'] = []

    # Process the frame if it was successfuly read
    if success:
        
        #################### Part 1 ####################
        # Object Detection & Coordiante Transofrmation #
        ################################################

        # Run YOLOv8 players inference on the frame
        results_players = model_players(frame, conf=player_model_conf_thresh)

        ## Extract detections information
        bboxes_p = results_players[0].boxes.xyxy.cpu().numpy()                # Detected players, referees and ball (x,y,x,y) bounding boxes
        bboxes_p_c = results_players[0].boxes.xywh.cpu().numpy()              # Detected players, referees and ball (x,y,w,h) bounding boxes    
        labels_p = list(results_players[0].boxes.cls.cpu().numpy())           # Detected players, referees and ball labels list
        confs_p = list(results_players[0].boxes.conf.cpu().numpy())           # Detected players, referees and ball confidence level

        # change
        # bboxes_p_c_0 = bboxes_p_c[[i==0 for i in labels_p],:]                 # Get bounding boxes information (x,y,w,h) of detected players (label 0)
        # bboxes_p_c_2 = bboxes_p_c[[i==2 for i in labels_p],:]                 # Get bounding boxes information (x,y,w,h) of detected ball(s) (label 2)
        bboxes_p_c_0 = bboxes_p_c[[i==0 or i==1 or i==2 or i==3 for i in labels_p],:]  # Get bounding boxes information (x,y,w,h) of detected players (label 0)
        bboxes_p_c_2 = bboxes_p_c[[i==4 for i in labels_p],:]                          # Get bounding boxes information (x,y,w,h) of detected ball(s) (label 2)

        # Get coordinates of detected players on frame (x_cencter, y_center+h/2)
        detected_ppos_src_pts = bboxes_p_c_0[:,:2]  + np.array([[0]*bboxes_p_c_0.shape[0], bboxes_p_c_0[:,3]/2]).transpose()
        # Get coordinates of the first detected ball (x_center, y_center)
        detected_ball_src_pos = bboxes_p_c_2[0,:2] if bboxes_p_c_2.shape[0]>0 else None

        # Transform players coordinates from frame plane to tactical map plance using the calculated Homography matrix
        pred_dst_pts = []                                                     # Initialize players tactical map coordiantes list
        for pt in detected_ppos_src_pts:     
            # print("Coor:", pt)
            pt = np.append(np.array(pt), np.array([1]), axis=0)               # Covert to homogeneous coordiantes
            dest_point = np.matmul(H, np.transpose(pt))                       # Apply homography transofrmation
            dest_point = dest_point/dest_point[2]           
            # print("map:", list(np.transpose(dest_point)[:2]))
            pred_dst_pts.append(list(np.transpose(dest_point)[:2]))           # Update players tactical map coordiantes list
        pred_dst_pts = np.array(pred_dst_pts)

        # Transform ball coordinates from frame plane to tactical map plane using the calculated Homography matrix
        if detected_ball_src_pos is not None:
            pt = np.append(np.array(detected_ball_src_pos), np.array([1]), axis=0)
            dest_point = np.matmul(H, np.transpose(pt))
            dest_point = dest_point/dest_point[2]
            detected_ball_dst_pos = np.transpose(dest_point)

            # Update track ball position history
            if len(ball_track_history['src'])>0 :
                if np.linalg.norm(detected_ball_src_pos-ball_track_history['src'][-1])<ball_track_dist_thresh:
                    ball_track_history['src'].append((int(detected_ball_src_pos[0]), int(detected_ball_src_pos[1])))
                    ball_track_history['dst'].append((int(detected_ball_dst_pos[0]), int(detected_ball_dst_pos[1])))
                else:
                    ball_track_history['src']=[(int(detected_ball_src_pos[0]), int(detected_ball_src_pos[1]))]
                    ball_track_history['dst']=[(int(detected_ball_dst_pos[0]), int(detected_ball_dst_pos[1]))]
            else:
                ball_track_history['src'].append((int(detected_ball_src_pos[0]), int(detected_ball_src_pos[1])))
                ball_track_history['dst'].append((int(detected_ball_dst_pos[0]), int(detected_ball_dst_pos[1])))
                
        # Remove oldest tracked ball postion if track exceedes threshold
        if len(ball_track_history) > max_track_length:
                ball_track_history['src'].pop(0)
                ball_track_history['dst'].pop(0)

        # After detection, populate the count for each detected class in the current frame
        for label in labels_p:
            if label in current_frame_class_counts:
                current_frame_class_counts[label] += 1
            else:
                current_frame_class_counts[label] = 1

        # Update the total detections for each class
        for label, count in current_frame_class_counts.items():
            if label in class_detection_counts:
                class_detection_counts[label] += count
            else:
                class_detection_counts[label] = count

        ######### Part 2 ########## 
        # Players Team Prediction #
        ###########################

        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)                    # Convert frame to RGB
        obj_palette_list = []                                                 # Initialize players color palette list
        palette_interval = (0,5)                                              # Color interval to extract from dominant colors palette (1rd to 5th color)
        annotated_frame = frame                                               # Create annotated frame 

        ## Loop over detected players (label 0) and extract dominant colors palette based on defined interval
        for i, j in enumerate(list(results_players[0].boxes.cls.cpu().numpy())):
            if int(j) == 0 or int(j) == 1 or int(j) == 2 or int(j) == 3:
            # if int(j) == 0:
            # change
                bbox = results_players[0].boxes.xyxy.cpu().numpy()[i,:]                         # Get bbox info (x,y,x,y)
                obj_img = frame_rgb[int(bbox[1]):int(bbox[3]), int(bbox[0]):int(bbox[2])]       # Crop bbox out of the frame
                obj_img_w, obj_img_h = obj_img.shape[1], obj_img.shape[0]

                center_filter_x1 = np.max([(obj_img_w//2)-(obj_img_w//5), 1])
                center_filter_x2 = (obj_img_w//2)+(obj_img_w//5)
                center_filter_y1 = np.max([(obj_img_h//3)-(obj_img_h//5), 1])
                center_filter_y2 = (obj_img_h//3)+(obj_img_h//5)
                center_filter = obj_img[center_filter_y1:center_filter_y2, 
                                        center_filter_x1:center_filter_x2]

                # obj_pil_img = Image.fromarray(np.uint8(center_filter))                        # Convert to pillow image
                obj_pil_img = Image.fromarray(np.uint8(center_filter))                          # Convert to pillow image

                reduced = obj_pil_img.convert("P", palette=Image.Palette.WEB)                   # Convert to web palette (216 colors)
                palette = reduced.getpalette()                                                  # Get palette as [r,g,b,r,g,b,...]
                palette = [palette[3*n:3*n+3] for n in range(256)]                              # Group 3 by 3 = [[r,g,b],[r,g,b],...]
                color_count = [(n, palette[m]) for n,m in reduced.getcolors()]                  # Create list of palette colors with their frequency
                RGB_df = pd.DataFrame(color_count, columns = ['cnt', 'RGB']).sort_values(       # Create dataframe based on defined palette interval
                                      by = 'cnt', ascending = False).iloc[
                                          palette_interval[0]:palette_interval[1],:]
                palette = list(RGB_df.RGB)                                                      # Convert palette to list (for faster processing)
                annotated_frame = cv2.rectangle(annotated_frame,                                # Add center filter bbox annotations
                                                (int(bbox[0])+center_filter_x1, 
                                                 int(bbox[1])+ center_filter_y1),  
                                                (int(bbox[0])+center_filter_x2, 
                                                 int(bbox[1])+center_filter_y2), (0,0,0), 2)
                
                # Update detected players color palette list
                obj_palette_list.append(palette)
        
        ## Calculate distances between each color from every detected player color palette and the predefined teams colors
        players_distance_features = []
        # Loop over detected players extracted color palettes
        for palette in obj_palette_list:
            palette_distance = []
            palette_lab = [skimage.color.rgb2lab([i/255 for i in color]) for color in palette]  # Convert colors to L*a*b* space
            # Loop over colors in palette
            for color in palette_lab:
                distance_list = []
                # Loop over predefined list of teams colors
                for c in color_list_lab:
                    distance = skimage.color.deltaE_cie76(color, c)                             # Calculate Euclidean distance in Lab color space
                    distance_list.append(distance)                                              # Update distance list for current color
                palette_distance.append(distance_list)                                          # Update distance list for current palette
            players_distance_features.append(palette_distance)                                  # Update distance features list

        ## Predict detected players teams based on distance features
        players_teams_list = []
        # Loop over players distance features
        for distance_feats in players_distance_features:
            vote_list=[]
            # Loop over distances for each color 
            for dist_list in distance_feats:
                team_idx = dist_list.index(min(dist_list))//nbr_team_colors                     # Assign team index for current color based on min distance
                vote_list.append(team_idx)                                                      # Update vote voting list with current color team prediction
            players_teams_list.append(max(vote_list, key=vote_list.count))                      # Predict current player team by vote counting

        #################### Part 3 #####################
        # Updated Frame & Tactical Map With Annotations #
        #################################################

        ball_color_bgr = (0,0,255)                                                              # Color (GBR) for ball annotation on tactical map
        j=0                                                                                     # Initializing counter of detected players
        palette_box_size = 5                                                                    # Set color box size in pixels (for display)

        # Loop over all detected object by players detection model
        for i in range(bboxes_p.shape[0]):
            conf = confs_p[i]                                                                   # Get confidence of current detected object
            # change
            # if labels_p[i]==0:                                                                  # Display annotation for detected players (label 0)
            if labels_p[i]==0 or labels_p[i]==1 or labels_p[i]==2 or labels_p[i]==3:
                # Display extracted color palette for each detected player
                palette = obj_palette_list[j]                                                               # Get color palette of the detected player
                for k, c in enumerate(palette):
                    c_bgr = c[::-1]                                                                         # Convert color to BGR
                    annotated_frame = cv2.rectangle(annotated_frame, (int(bboxes_p[i,2])+3,                 # Add color palette annotation on frame
                                                            int(bboxes_p[i,1])+k*palette_box_size),
                                                            (int(bboxes_p[i,2])+palette_box_size,
                                                            int(bboxes_p[i,1])+(palette_box_size)*(k+1)),
                                                              c_bgr, -1)

                team_name = list(colors_dic.keys())[players_teams_list[j]]                                  # Get detected player team prediction
                color_rgb = colors_dic[team_name][0]                                                        # Get detected player team color
                color_bgr = color_rgb[::-1]                                                                 # Convert color to bgr

                annotated_frame = cv2.rectangle(annotated_frame, (int(bboxes_p[i,0]), int(bboxes_p[i,1])),  # Add bbox annotations with team colors
                                                (int(bboxes_p[i,2]), int(bboxes_p[i,3])), color_bgr, 1)
                
                cv2.putText(annotated_frame, team_name + f" {conf:.2f}",                                    # Add team name annotations
                             (int(bboxes_p[i,0]), int(bboxes_p[i,1])-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5,
                               color_bgr, 2)
                
                if color_bgr == (255, 255, 255):
                    color_bgr = (0,0,0) 
                
                # Add tactical map player postion color coded annotation
                tac_map_copy = cv2.circle(tac_map_copy, (abs(int(pred_dst_pts[j][0])),abs(int(pred_dst_pts[j][1]))),
                                          radius=5, color=color_bgr , thickness=-1)          
                j+=1                                                                                        # Update players counter
                
            else:                                                                                            # Display annotation for other detections (label 1, 2)
                annotated_frame = cv2.rectangle(annotated_frame, (int(bboxes_p[i,0]), int(bboxes_p[i,1])),  
                                                 (int(bboxes_p[i,2]), int(bboxes_p[i,3])), (255,255,255), 4) # Add white colored bbox annotations
                cv2.putText(annotated_frame, labels_dic[int(labels_p[i])] + f" {conf:.2f}",
                            (int(bboxes_p[i,0]), int(bboxes_p[i,1])-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5,
                              (255,255,255), 2)                                                              # Add white colored label text annotations
                print(labels_dic[int(labels_p[i])])
                # Add tactical map ball postion annotation if detected
                if detected_ball_src_pos is not None:
                    tac_map_copy = cv2.circle(tac_map_copy, (int(detected_ball_dst_pos[0]), 
                                                             int(detected_ball_dst_pos[1])), radius=5, 
                                                             color=ball_color_bgr, thickness=3)
        
        # Plot the ball tracks on tactical map
        if len(ball_track_history['src'])>0:
            points = np.hstack(ball_track_history['dst']).astype(np.int32).reshape((-1, 1, 2))
            tac_map_copy = cv2.polylines(tac_map_copy, [points], isClosed=False, color=(0, 0, 100), thickness=2)
        
        # Combine annotated frame and tactical map in one image with colored border separation
        border_color = [255,255,255]                                                                        # Set border color (BGR)
        annotated_frame=cv2.copyMakeBorder(annotated_frame, 40, 10, 10, 10,                                 # Add borders to annotated frame
                                            cv2.BORDER_CONSTANT, value=border_color)
        tac_map_copy = cv2.rotate(tac_map_copy, cv2.ROTATE_90_COUNTERCLOCKWISE)                             # 90 degrees rotation

        # Calculate the position to start the overlay (top right corner)
        start_y = 50
        start_x = annotated_frame.shape[1] - tac_map_copy.shape[1] - 50 # Start at the right edge of the annotated_frame

        annotated_frame[start_y:start_y + tac_map_copy.shape[0], start_x:start_x + tac_map_copy.shape[1]] = tac_map_copy

        final_img = annotated_frame

        ## Add info annotation
        cv2.putText(final_img, "Press 'p' to pause & 'q' to quit", (300,30), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0,0,0), 2)

        new_frame_time = time.time()                                                                        # Get time after finished processing current frame
        fps = 1/(new_frame_time-prev_frame_time)                                                            # Calculate FPS as 1/(frame proceesing duration)
        prev_frame_time = new_frame_time                                                                    # Save current time to be used in next frame
        cv2.putText(final_img, "FPS: " + str(int(fps)), (20,30), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0,0,0), 2)
        
        # Display the final annotated frame
        cv2.imshow("YOLOv8 Players and Field Keypoints Detection with Team Prediction and Tactical Map",    
                    final_img)
        
        frame_filename = os.path.join(frame_save_path, f'frame_{frame_nbr:04d}.jpg')
        cv2.imwrite(frame_filename, final_img)  # Save the frame as JPEG file

        # Treat keyboard user inputs ("p" for pause/unpause & "q" for quit)
        key = cv2.waitKey(1)
        # Break the loop if 'q' is pressed
        if key == ord("q"):
            break
        if key == ord('p'):
            cv2.waitKey(-1) #wait until any key is pressed
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 416x736 16 Players, 1 GoalKeeper, 271.9ms
# Speed: 7.1ms preprocess, 271.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 1 GoalKeeper, 221.9ms
# Speed: 1.6ms preprocess, 221.9ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 1 GoalKeeper, 232.5ms
# Speed: 1.7ms preprocess, 232.5ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 1 GoalKeeper, 227.9ms
# Speed: 1.7ms preprocess, 227.9ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 2 GoalKeepers, 223.5ms
# Speed: 1.6ms preprocess, 223.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 2 GoalKeepers, 220.3ms
# Speed: 1.6ms preprocess, 220.3ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 15 Players, 1 GoalKeeper, 236.7ms
# Speed: 1.7ms preprocess, 236.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 15 Players, 1 GoalKeeper, 477.0ms
# Speed: 1.6ms preprocess, 477.0ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 14 Players, 1 GoalKeeper, 273.2ms
# Speed: 2.1ms preprocess, 273.2ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 1 GoalKeeper, 210.9ms
# Speed: 1.8ms preprocess, 210.9ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 1 GoalKeeper, 204.6ms
# Speed: 2.2ms preprocess, 204.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 1 GoalKeeper, 193.5ms
# Speed: 1.8ms preprocess, 193.5ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 1 GoalKeeper, 204.9ms
# Speed: 1.6ms preprocess, 204.9ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 1 GoalKeeper, 200.2ms
# Speed: 1.9ms preprocess, 200.2ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 15 Players, 2 GoalKeepers, 191.9ms
# Speed: 1.7ms preprocess, 191.9ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 1 GoalKeeper, 193.2ms
# Speed: 1.4ms preprocess, 193.2ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 1 GoalKeeper, 195.4ms
# Speed: 1.7ms preprocess, 195.4ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 15 Players, 1 GoalKeeper, 196.1ms
# Speed: 1.7ms preprocess, 196.1ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 15 Players, 2 GoalKeepers, 203.3ms
# Speed: 2.2ms preprocess, 203.3ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 14 Players, 2 GoalKeepers, 198.5ms
# Speed: 1.7ms preprocess, 198.5ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 15 Players, 1 GoalKeeper, 1 Main Referee, 196.7ms
# Speed: 1.5ms preprocess, 196.7ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 1 GoalKeeper, 193.1ms
# Speed: 1.6ms preprocess, 193.1ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 1 GoalKeeper, 196.2ms
# Speed: 1.5ms preprocess, 196.2ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 1 GoalKeeper, 194.6ms
# Speed: 2.0ms preprocess, 194.6ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 1 GoalKeeper, 196.0ms
# Speed: 1.5ms preprocess, 196.0ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 197.6ms
# Speed: 1.7ms preprocess, 197.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 1 GoalKeeper, 196.2ms
# Speed: 1.5ms preprocess, 196.2ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 196.7ms
# Speed: 1.5ms preprocess, 196.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 195.2ms
# Speed: 1.5ms preprocess, 195.2ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 196.0ms
# Speed: 1.6ms preprocess, 196.0ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 197.2ms
# Speed: 1.8ms preprocess, 197.2ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 1 GoalKeeper, 194.6ms
# Speed: 1.5ms preprocess, 194.6ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 1 GoalKeeper, 1 Side Referee, 200.3ms
# Speed: 1.5ms preprocess, 200.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
# Ball
#
# 0: 416x736 18 Players, 1 GoalKeeper, 198.1ms
# Speed: 1.5ms preprocess, 198.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 1 GoalKeeper, 202.7ms
# Speed: 1.6ms preprocess, 202.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 1 GoalKeeper, 196.8ms
# Speed: 1.4ms preprocess, 196.8ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 1 GoalKeeper, 200.0ms
# Speed: 1.6ms preprocess, 200.0ms inference, 0.3ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 1 GoalKeeper, 197.7ms
# Speed: 1.5ms preprocess, 197.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 1 GoalKeeper, 195.2ms
# Speed: 1.4ms preprocess, 195.2ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 1 GoalKeeper, 194.2ms
# Speed: 1.7ms preprocess, 194.2ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 1 GoalKeeper, 196.4ms
# Speed: 1.5ms preprocess, 196.4ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 1 GoalKeeper, 199.0ms
# Speed: 1.5ms preprocess, 199.0ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 1 GoalKeeper, 194.3ms
# Speed: 1.6ms preprocess, 194.3ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 1 GoalKeeper, 194.1ms
# Speed: 1.7ms preprocess, 194.1ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 2 GoalKeepers, 198.1ms
# Speed: 1.5ms preprocess, 198.1ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 1 GoalKeeper, 193.4ms
# Speed: 1.5ms preprocess, 193.4ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 1 GoalKeeper, 196.0ms
# Speed: 1.7ms preprocess, 196.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 1 GoalKeeper, 192.5ms
# Speed: 1.9ms preprocess, 192.5ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 1 GoalKeeper, 257.2ms
# Speed: 1.5ms preprocess, 257.2ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 1 GoalKeeper, 195.8ms
# Speed: 1.5ms preprocess, 195.8ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 1 GoalKeeper, 206.1ms
# Speed: 1.6ms preprocess, 206.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 1 GoalKeeper, 197.1ms
# Speed: 1.6ms preprocess, 197.1ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 1 GoalKeeper, 200.6ms
# Speed: 1.4ms preprocess, 200.6ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 1 GoalKeeper, 213.3ms
# Speed: 1.5ms preprocess, 213.3ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 364.3ms
# Speed: 3.8ms preprocess, 364.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 233.5ms
# Speed: 1.6ms preprocess, 233.5ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 1 GoalKeeper, 247.1ms
# Speed: 1.6ms preprocess, 247.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 1 GoalKeeper, 195.2ms
# Speed: 1.5ms preprocess, 195.2ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 198.4ms
# Speed: 1.7ms preprocess, 198.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 193.3ms
# Speed: 1.6ms preprocess, 193.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 198.5ms
# Speed: 1.5ms preprocess, 198.5ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 195.8ms
# Speed: 1.5ms preprocess, 195.8ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 15 Players, 207.3ms
# Speed: 1.7ms preprocess, 207.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 196.6ms
# Speed: 1.6ms preprocess, 196.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 275.4ms
# Speed: 1.8ms preprocess, 275.4ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 14 Players, 211.8ms
# Speed: 1.6ms preprocess, 211.8ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 13 Players, 1 GoalKeeper, 265.3ms
# Speed: 1.8ms preprocess, 265.3ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 15 Players, 1 GoalKeeper, 244.1ms
# Speed: 2.1ms preprocess, 244.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 13 Players, 1 GoalKeeper, 1 Main Referee, 210.6ms
# Speed: 1.6ms preprocess, 210.6ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 12 Players, 217.6ms
# Speed: 1.5ms preprocess, 217.6ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 12 Players, 254.3ms
# Speed: 1.6ms preprocess, 254.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 11 Players, 262.7ms
# Speed: 1.6ms preprocess, 262.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 13 Players, 212.8ms
# Speed: 2.1ms preprocess, 212.8ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 15 Players, 228.5ms
# Speed: 1.4ms preprocess, 228.5ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 1 GoalKeeper, 1 Main Referee, 226.9ms
# Speed: 1.6ms preprocess, 226.9ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 14 Players, 1 GoalKeeper, 209.2ms
# Speed: 1.5ms preprocess, 209.2ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 1 GoalKeeper, 424.9ms
# Speed: 8.4ms preprocess, 424.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 15 Players, 1 GoalKeeper, 248.2ms
# Speed: 1.8ms preprocess, 248.2ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 1 GoalKeeper, 208.7ms
# Speed: 1.7ms preprocess, 208.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 1 GoalKeeper, 210.4ms
# Speed: 1.8ms preprocess, 210.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 1 GoalKeeper, 211.3ms
# Speed: 1.6ms preprocess, 211.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 1 GoalKeeper, 201.3ms
# Speed: 1.8ms preprocess, 201.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 216.1ms
# Speed: 1.5ms preprocess, 216.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 1 Main Referee, 211.4ms
# Speed: 1.5ms preprocess, 211.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 219.8ms
# Speed: 1.9ms preprocess, 219.8ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 210.0ms
# Speed: 1.5ms preprocess, 210.0ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 208.7ms
# Speed: 2.0ms preprocess, 208.7ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 210.3ms
# Speed: 1.6ms preprocess, 210.3ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 213.3ms
# Speed: 1.6ms preprocess, 213.3ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 206.2ms
# Speed: 1.5ms preprocess, 206.2ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 212.1ms
# Speed: 1.6ms preprocess, 212.1ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 208.0ms
# Speed: 1.9ms preprocess, 208.0ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 213.1ms
# Speed: 1.5ms preprocess, 213.1ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 1 Main Referee, 206.0ms
# Speed: 1.5ms preprocess, 206.0ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 212.6ms
# Speed: 1.5ms preprocess, 212.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 209.6ms
# Speed: 1.6ms preprocess, 209.6ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 323.5ms
# Speed: 1.5ms preprocess, 323.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 1 Main Referee, 241.7ms
# Speed: 1.8ms preprocess, 241.7ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 1 Main Referee, 207.4ms
# Speed: 1.9ms preprocess, 207.4ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 1 Main Referee, 205.3ms
# Speed: 1.5ms preprocess, 205.3ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 208.3ms
# Speed: 1.5ms preprocess, 208.3ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 1 Main Referee, 205.1ms
# Speed: 1.6ms preprocess, 205.1ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 1 Side Referee, 211.5ms
# Speed: 1.6ms preprocess, 211.5ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
# Ball
#
# 0: 416x736 16 Players, 208.4ms
# Speed: 1.6ms preprocess, 208.4ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 226.1ms
# Speed: 1.9ms preprocess, 226.1ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 207.4ms
# Speed: 1.7ms preprocess, 207.4ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 214.8ms
# Speed: 1.5ms preprocess, 214.8ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 207.7ms
# Speed: 1.5ms preprocess, 207.7ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 1 Main Referee, 1 Side Referee, 210.5ms
# Speed: 1.7ms preprocess, 210.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
# Ball
#
# 0: 416x736 15 Players, 1 Side Referee, 264.5ms
# Speed: 1.7ms preprocess, 264.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
# Ball
#
# 0: 416x736 17 Players, 1 Main Referee, 1 Side Referee, 227.6ms
# Speed: 1.5ms preprocess, 227.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
# Ball
#
# 0: 416x736 17 Players, 205.4ms
# Speed: 1.7ms preprocess, 205.4ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 252.8ms
# Speed: 1.7ms preprocess, 252.8ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 251.3ms
# Speed: 1.6ms preprocess, 251.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 1 GoalKeeper, 276.7ms
# Speed: 1.8ms preprocess, 276.7ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 244.3ms
# Speed: 2.1ms preprocess, 244.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 236.4ms
# Speed: 1.7ms preprocess, 236.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 249.3ms
# Speed: 1.6ms preprocess, 249.3ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 1 GoalKeeper, 280.2ms
# Speed: 3.1ms preprocess, 280.2ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 1 GoalKeeper, 476.0ms
# Speed: 2.5ms preprocess, 476.0ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 15 Players, 1 GoalKeeper, 322.2ms
# Speed: 2.1ms preprocess, 322.2ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 14 Players, 1 GoalKeeper, 225.7ms
# Speed: 1.6ms preprocess, 225.7ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 14 Players, 1 GoalKeeper, 217.1ms
# Speed: 1.6ms preprocess, 217.1ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 14 Players, 1 GoalKeeper, 212.2ms
# Speed: 1.7ms preprocess, 212.2ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 15 Players, 1 GoalKeeper, 223.1ms
# Speed: 1.9ms preprocess, 223.1ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 15 Players, 1 GoalKeeper, 238.3ms
# Speed: 1.6ms preprocess, 238.3ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 15 Players, 1 GoalKeeper, 232.0ms
# Speed: 1.6ms preprocess, 232.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 214.9ms
# Speed: 1.5ms preprocess, 214.9ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 232.4ms
# Speed: 2.6ms preprocess, 232.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 218.5ms
# Speed: 1.6ms preprocess, 218.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 218.9ms
# Speed: 1.5ms preprocess, 218.9ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 221.3ms
# Speed: 1.9ms preprocess, 221.3ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 227.9ms
# Speed: 1.5ms preprocess, 227.9ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 224.4ms
# Speed: 1.5ms preprocess, 224.4ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 244.9ms
# Speed: 1.6ms preprocess, 244.9ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 216.4ms
# Speed: 1.5ms preprocess, 216.4ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 221.4ms
# Speed: 1.5ms preprocess, 221.4ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 15 Players, 218.4ms
# Speed: 1.6ms preprocess, 218.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 15 Players, 220.4ms
# Speed: 1.6ms preprocess, 220.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 258.6ms
# Speed: 1.5ms preprocess, 258.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 1 Side Referee, 477.4ms
# Speed: 2.0ms preprocess, 477.4ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 736)
# Ball
#
# 0: 416x736 16 Players, 282.0ms
# Speed: 11.2ms preprocess, 282.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 1 Main Referee, 230.7ms
# Speed: 1.6ms preprocess, 230.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 1 Main Referee, 206.7ms
# Speed: 1.5ms preprocess, 206.7ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 15 Players, 1 Main Referee, 238.6ms
# Speed: 1.6ms preprocess, 238.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 15 Players, 1 Main Referee, 214.6ms
# Speed: 1.5ms preprocess, 214.6ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 14 Players, 1 Main Referee, 214.4ms
# Speed: 1.4ms preprocess, 214.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 14 Players, 1 Main Referee, 203.6ms
# Speed: 1.7ms preprocess, 203.6ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 15 Players, 215.7ms
# Speed: 1.5ms preprocess, 215.7ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 212.4ms
# Speed: 1.5ms preprocess, 212.4ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 207.9ms
# Speed: 1.5ms preprocess, 207.9ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 15 Players, 216.5ms
# Speed: 1.5ms preprocess, 216.5ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 244.8ms
# Speed: 1.6ms preprocess, 244.8ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 216.8ms
# Speed: 1.7ms preprocess, 216.8ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 248.6ms
# Speed: 1.5ms preprocess, 248.6ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 208.8ms
# Speed: 1.6ms preprocess, 208.8ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 221.7ms
# Speed: 1.5ms preprocess, 221.7ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 215.7ms
# Speed: 1.5ms preprocess, 215.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 228.3ms
# Speed: 1.6ms preprocess, 228.3ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 215.2ms
# Speed: 1.5ms preprocess, 215.2ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 255.2ms
# Speed: 1.7ms preprocess, 255.2ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 227.1ms
# Speed: 1.6ms preprocess, 227.1ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 239.4ms
# Speed: 1.7ms preprocess, 239.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 214.7ms
# Speed: 1.9ms preprocess, 214.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 215.5ms
# Speed: 1.5ms preprocess, 215.5ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 1 Main Referee, 210.1ms
# Speed: 1.5ms preprocess, 210.1ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 1 Main Referee, 218.6ms
# Speed: 1.8ms preprocess, 218.6ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 211.4ms
# Speed: 1.5ms preprocess, 211.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 213.6ms
# Speed: 1.7ms preprocess, 213.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 215.7ms
# Speed: 1.4ms preprocess, 215.7ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 217.5ms
# Speed: 1.7ms preprocess, 217.5ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 248.4ms
# Speed: 1.6ms preprocess, 248.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 228.6ms
# Speed: 2.3ms preprocess, 228.6ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 1 Main Referee, 233.5ms
# Speed: 1.6ms preprocess, 233.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 245.1ms
# Speed: 1.8ms preprocess, 245.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 218.4ms
# Speed: 1.8ms preprocess, 218.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 216.5ms
# Speed: 1.6ms preprocess, 216.5ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 1 Main Referee, 415.4ms
# Speed: 1.7ms preprocess, 415.4ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 1 Main Referee, 261.4ms
# Speed: 2.0ms preprocess, 261.4ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 1 Main Referee, 206.0ms
# Speed: 1.5ms preprocess, 206.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 1 Main Referee, 220.6ms
# Speed: 2.0ms preprocess, 220.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 211.2ms
# Speed: 1.8ms preprocess, 211.2ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 237.0ms
# Speed: 1.5ms preprocess, 237.0ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 1 Side Referee, 227.7ms
# Speed: 1.8ms preprocess, 227.7ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
# Ball
#
# 0: 416x736 18 Players, 220.5ms
# Speed: 1.5ms preprocess, 220.5ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 196.8ms
# Speed: 1.9ms preprocess, 196.8ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 209.4ms
# Speed: 1.5ms preprocess, 209.4ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 197.4ms
# Speed: 1.5ms preprocess, 197.4ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 193.5ms
# Speed: 1.6ms preprocess, 193.5ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 196.2ms
# Speed: 1.6ms preprocess, 196.2ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 218.7ms
# Speed: 1.4ms preprocess, 218.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 196.5ms
# Speed: 1.4ms preprocess, 196.5ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 194.0ms
# Speed: 1.5ms preprocess, 194.0ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 192.2ms
# Speed: 1.8ms preprocess, 192.2ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 195.6ms
# Speed: 1.5ms preprocess, 195.6ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 199.8ms
# Speed: 1.8ms preprocess, 199.8ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 202.2ms
# Speed: 1.6ms preprocess, 202.2ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 195.4ms
# Speed: 1.4ms preprocess, 195.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 1 Main Referee, 193.5ms
# Speed: 1.7ms preprocess, 193.5ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 195.4ms
# Speed: 1.7ms preprocess, 195.4ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 20 Players, 197.4ms
# Speed: 1.9ms preprocess, 197.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 20 Players, 198.4ms
# Speed: 1.6ms preprocess, 198.4ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 200.8ms
# Speed: 1.5ms preprocess, 200.8ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 197.7ms
# Speed: 1.5ms preprocess, 197.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 193.4ms
# Speed: 1.5ms preprocess, 193.4ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 196.0ms
# Speed: 1.5ms preprocess, 196.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 202.0ms
# Speed: 1.5ms preprocess, 202.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 198.1ms
# Speed: 1.7ms preprocess, 198.1ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 195.2ms
# Speed: 1.5ms preprocess, 195.2ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 197.3ms
# Speed: 1.4ms preprocess, 197.3ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 367.4ms
# Speed: 1.6ms preprocess, 367.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 20 Players, 230.4ms
# Speed: 1.6ms preprocess, 230.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 248.6ms
# Speed: 1.6ms preprocess, 248.6ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 20 Players, 197.2ms
# Speed: 1.5ms preprocess, 197.2ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 1 Side Referee, 305.8ms
# Speed: 2.0ms preprocess, 305.8ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
# Ball
#
# 0: 416x736 20 Players, 207.5ms
# Speed: 1.7ms preprocess, 207.5ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 271.2ms
# Speed: 1.8ms preprocess, 271.2ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 275.6ms
# Speed: 5.7ms preprocess, 275.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 20 Players, 309.9ms
# Speed: 2.0ms preprocess, 309.9ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 20 Players, 198.8ms
# Speed: 1.7ms preprocess, 198.8ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 1 Main Referee, 208.9ms
# Speed: 1.6ms preprocess, 208.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 1 Main Referee, 196.5ms
# Speed: 1.5ms preprocess, 196.5ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 1 Main Referee, 308.4ms
# Speed: 1.4ms preprocess, 308.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 216.8ms
# Speed: 1.5ms preprocess, 216.8ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 254.4ms
# Speed: 1.6ms preprocess, 254.4ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 198.3ms
# Speed: 1.7ms preprocess, 198.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 20 Players, 197.8ms
# Speed: 1.6ms preprocess, 197.8ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 197.2ms
# Speed: 1.7ms preprocess, 197.2ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 199.3ms
# Speed: 1.6ms preprocess, 199.3ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 197.7ms
# Speed: 1.5ms preprocess, 197.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 200.1ms
# Speed: 1.5ms preprocess, 200.1ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 199.5ms
# Speed: 1.6ms preprocess, 199.5ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 215.3ms
# Speed: 1.7ms preprocess, 215.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 20 Players, 234.2ms
# Speed: 1.6ms preprocess, 234.2ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 218.6ms
# Speed: 1.6ms preprocess, 218.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 281.0ms
# Speed: 1.9ms preprocess, 281.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 214.7ms
# Speed: 1.9ms preprocess, 214.7ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 319.0ms
# Speed: 1.7ms preprocess, 319.0ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 1 Main Referee, 407.2ms
# Speed: 7.2ms preprocess, 407.2ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 1 GoalKeeper, 308.9ms
# Speed: 1.9ms preprocess, 308.9ms inference, 4.2ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 1 GoalKeeper, 272.0ms
# Speed: 2.2ms preprocess, 272.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 1 GoalKeeper, 1 Main Referee, 221.7ms
# Speed: 2.2ms preprocess, 221.7ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 1 GoalKeeper, 244.9ms
# Speed: 1.5ms preprocess, 244.9ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 1 Main Referee, 241.4ms
# Speed: 1.6ms preprocess, 241.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 242.3ms
# Speed: 1.6ms preprocess, 242.3ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 257.5ms
# Speed: 1.6ms preprocess, 257.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 275.8ms
# Speed: 1.5ms preprocess, 275.8ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 20 Players, 260.3ms
# Speed: 2.7ms preprocess, 260.3ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 238.4ms
# Speed: 1.8ms preprocess, 238.4ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 527.2ms
# Speed: 1.7ms preprocess, 527.2ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 20 Players, 351.5ms
# Speed: 1.8ms preprocess, 351.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 20 Players, 224.1ms
# Speed: 2.0ms preprocess, 224.1ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 20 Players, 269.4ms
# Speed: 1.8ms preprocess, 269.4ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 20 Players, 225.2ms
# Speed: 1.6ms preprocess, 225.2ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 1 GoalKeeper, 220.2ms
# Speed: 1.6ms preprocess, 220.2ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 1 GoalKeeper, 227.8ms
# Speed: 1.7ms preprocess, 227.8ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 20 Players, 231.0ms
# Speed: 2.5ms preprocess, 231.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 20 Players, 227.1ms
# Speed: 1.5ms preprocess, 227.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 20 Players, 221.4ms
# Speed: 2.1ms preprocess, 221.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 231.4ms
# Speed: 1.6ms preprocess, 231.4ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 225.2ms
# Speed: 1.6ms preprocess, 225.2ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 20 Players, 237.1ms
# Speed: 1.6ms preprocess, 237.1ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 232.7ms
# Speed: 1.6ms preprocess, 232.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 1 GoalKeeper, 217.0ms
# Speed: 1.7ms preprocess, 217.0ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 1 GoalKeeper, 220.2ms
# Speed: 1.4ms preprocess, 220.2ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 213.6ms
# Speed: 1.5ms preprocess, 213.6ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 228.2ms
# Speed: 1.7ms preprocess, 228.2ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 228.8ms
# Speed: 1.4ms preprocess, 228.8ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 249.1ms
# Speed: 1.9ms preprocess, 249.1ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 230.3ms
# Speed: 1.8ms preprocess, 230.3ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 233.3ms
# Speed: 1.6ms preprocess, 233.3ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 232.6ms
# Speed: 1.8ms preprocess, 232.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 15 Players, 229.9ms
# Speed: 1.7ms preprocess, 229.9ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 1 Side Referee, 228.2ms
# Speed: 1.6ms preprocess, 228.2ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
# Ball
#
# 0: 416x736 17 Players, 1 Side Referee, 215.3ms
# Speed: 1.7ms preprocess, 215.3ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
# Ball
#
# 0: 416x736 18 Players, 1 Side Referee, 244.1ms
# Speed: 1.6ms preprocess, 244.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
# Ball
#
# 0: 416x736 16 Players, 1 Side Referee, 217.0ms
# Speed: 1.5ms preprocess, 217.0ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
# Ball
#
# 0: 416x736 16 Players, 1 GoalKeeper, 242.4ms
# Speed: 1.7ms preprocess, 242.4ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 231.3ms
# Speed: 2.8ms preprocess, 231.3ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 234.1ms
# Speed: 1.6ms preprocess, 234.1ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 229.4ms
# Speed: 2.1ms preprocess, 229.4ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 231.5ms
# Speed: 1.9ms preprocess, 231.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 238.8ms
# Speed: 1.5ms preprocess, 238.8ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 236.2ms
# Speed: 1.9ms preprocess, 236.2ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 233.1ms
# Speed: 1.7ms preprocess, 233.1ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 15 Players, 222.7ms
# Speed: 1.8ms preprocess, 222.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 226.9ms
# Speed: 2.0ms preprocess, 226.9ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 392.9ms
# Speed: 1.5ms preprocess, 392.9ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 276.1ms
# Speed: 1.9ms preprocess, 276.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 228.4ms
# Speed: 1.7ms preprocess, 228.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 226.1ms
# Speed: 2.5ms preprocess, 226.1ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 230.7ms
# Speed: 1.6ms preprocess, 230.7ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 214.1ms
# Speed: 1.5ms preprocess, 214.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 226.4ms
# Speed: 1.8ms preprocess, 226.4ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 212.3ms
# Speed: 1.7ms preprocess, 212.3ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 1 Main Referee, 215.5ms
# Speed: 2.1ms preprocess, 215.5ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 222.4ms
# Speed: 1.4ms preprocess, 222.4ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 1 Main Referee, 217.0ms
# Speed: 1.5ms preprocess, 217.0ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 15 Players, 233.2ms
# Speed: 1.8ms preprocess, 233.2ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 223.5ms
# Speed: 1.6ms preprocess, 223.5ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 211.8ms
# Speed: 1.7ms preprocess, 211.8ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 225.3ms
# Speed: 1.9ms preprocess, 225.3ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 212.8ms
# Speed: 1.6ms preprocess, 212.8ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 226.7ms
# Speed: 1.5ms preprocess, 226.7ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 232.3ms
# Speed: 1.8ms preprocess, 232.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 226.0ms
# Speed: 1.6ms preprocess, 226.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 214.8ms
# Speed: 1.5ms preprocess, 214.8ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 213.7ms
# Speed: 2.0ms preprocess, 213.7ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 215.5ms
# Speed: 1.7ms preprocess, 215.5ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 1 Main Referee, 211.4ms
# Speed: 1.9ms preprocess, 211.4ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 1 Main Referee, 244.8ms
# Speed: 1.6ms preprocess, 244.8ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 1 Main Referee, 214.0ms
# Speed: 1.6ms preprocess, 214.0ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 1 Main Referee, 209.9ms
# Speed: 1.7ms preprocess, 209.9ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 233.8ms
# Speed: 1.7ms preprocess, 233.8ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 1 Main Referee, 227.2ms
# Speed: 1.7ms preprocess, 227.2ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 1 Main Referee, 372.4ms
# Speed: 1.9ms preprocess, 372.4ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 1 Main Referee, 226.3ms
# Speed: 1.8ms preprocess, 226.3ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 15 Players, 220.2ms
# Speed: 1.7ms preprocess, 220.2ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 220.4ms
# Speed: 1.6ms preprocess, 220.4ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 232.9ms
# Speed: 1.7ms preprocess, 232.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 210.8ms
# Speed: 1.5ms preprocess, 210.8ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 239.2ms
# Speed: 1.6ms preprocess, 239.2ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 230.8ms
# Speed: 1.5ms preprocess, 230.8ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 386.6ms
# Speed: 1.7ms preprocess, 386.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 234.2ms
# Speed: 2.1ms preprocess, 234.2ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 228.9ms
# Speed: 1.6ms preprocess, 228.9ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 214.8ms
# Speed: 1.9ms preprocess, 214.8ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 1 Main Referee, 232.2ms
# Speed: 1.6ms preprocess, 232.2ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 1 Main Referee, 219.5ms
# Speed: 1.5ms preprocess, 219.5ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 1 Main Referee, 222.6ms
# Speed: 2.0ms preprocess, 222.6ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 1 Main Referee, 214.2ms
# Speed: 1.4ms preprocess, 214.2ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 15 Players, 1 Main Referee, 227.9ms
# Speed: 1.6ms preprocess, 227.9ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 15 Players, 1 Main Referee, 231.0ms
# Speed: 1.9ms preprocess, 231.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 1 Main Referee, 229.2ms
# Speed: 1.5ms preprocess, 229.2ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 1 Main Referee, 250.2ms
# Speed: 2.0ms preprocess, 250.2ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 1 Main Referee, 226.9ms
# Speed: 1.6ms preprocess, 226.9ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 1 GoalKeeper, 3 Main Referees, 277.8ms
# Speed: 1.9ms preprocess, 277.8ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 1 GoalKeeper, 1 Main Referee, 223.5ms
# Speed: 1.6ms preprocess, 223.5ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 1 GoalKeeper, 224.0ms
# Speed: 1.5ms preprocess, 224.0ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 1 GoalKeeper, 210.4ms
# Speed: 1.7ms preprocess, 210.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 212.4ms
# Speed: 1.5ms preprocess, 212.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 218.7ms
# Speed: 1.6ms preprocess, 218.7ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 218.3ms
# Speed: 2.1ms preprocess, 218.3ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 385.5ms
# Speed: 1.6ms preprocess, 385.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 19 Players, 329.8ms
# Speed: 7.3ms preprocess, 329.8ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 228.1ms
# Speed: 1.6ms preprocess, 228.1ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 218.5ms
# Speed: 1.9ms preprocess, 218.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 218.3ms
# Speed: 2.2ms preprocess, 218.3ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 223.3ms
# Speed: 1.5ms preprocess, 223.3ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 18 Players, 216.3ms
# Speed: 1.6ms preprocess, 216.3ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 1 Side Referee, 215.3ms
# Speed: 1.7ms preprocess, 215.3ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
# Ball
#
# 0: 416x736 17 Players, 1 Main Referee, 220.1ms
# ...
#
# 0: 416x736 15 Players, 2 Main Referees, 198.0ms
# Speed: 1.5ms preprocess, 198.0ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 14 Players, 1 Main Referee, 210.7ms
# Speed: 1.8ms preprocess, 210.7ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 14 Players, 203.2ms
# Speed: 1.7ms preprocess, 203.2ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 15 Players, 1 Staff Member, 224.0ms
# Speed: 2.5ms preprocess, 224.0ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 736)
# Main referee
#
# 0: 416x736 14 Players, 1 Main Referee, 196.9ms
# Speed: 1.7ms preprocess, 196.9ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 15 Players, 198.4ms
# Speed: 1.4ms preprocess, 198.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 253.7ms
# Speed: 1.5ms preprocess, 253.7ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 15 Players, 341.1ms
# Speed: 4.1ms preprocess, 341.1ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 235.1ms
# Speed: 2.3ms preprocess, 235.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 198.1ms
# Speed: 1.5ms preprocess, 198.1ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 17 Players, 193.2ms
# Speed: 1.6ms preprocess, 193.2ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 16 Players, 1 Staff Member, 195.3ms
# Speed: 1.6ms preprocess, 195.3ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
# Main referee
#
# 0: 416x736 15 Players, 192.8ms
# Speed: 1.6ms preprocess, 192.8ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 15 Players, 206.3ms
# Speed: 1.6ms preprocess, 206.3ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 15 Players, 203.2ms
# Speed: 1.5ms preprocess, 203.2ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 15 Players, 1 Main Referee, 193.5ms
# Speed: 1.7ms preprocess, 193.5ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 14 Players, 1 Main Referee, 196.0ms
# Speed: 1.5ms preprocess, 196.0ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 12 Players, 1 Main Referee, 198.5ms
# Speed: 1.8ms preprocess, 198.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 13 Players, 1 Main Referee, 196.9ms
# Speed: 2.0ms preprocess, 196.9ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 13 Players, 2 Main Referees, 199.4ms
# Speed: 1.5ms preprocess, 199.4ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 14 Players, 1 Main Referee, 204.2ms
# Speed: 1.5ms preprocess, 204.2ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 14 Players, 1 Main Referee, 198.5ms
# Speed: 1.4ms preprocess, 198.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 13 Players, 1 Main Referee, 195.7ms
# Speed: 1.7ms preprocess, 195.7ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 14 Players, 200.6ms
# Speed: 1.4ms preprocess, 200.6ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 14 Players, 192.5ms
# Speed: 1.6ms preprocess, 192.5ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 15 Players, 201.6ms
# Speed: 2.0ms preprocess, 201.6ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 15 Players, 198.8ms
# Speed: 1.5ms preprocess, 198.8ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 15 Players, 198.4ms
# Speed: 1.6ms preprocess, 198.4ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 14 Players, 1 Main Referee, 249.8ms
# Speed: 1.5ms preprocess, 249.8ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 15 Players, 391.4ms
# Speed: 7.5ms preprocess, 391.4ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 13 Players, 199.0ms
# Speed: 1.7ms preprocess, 199.0ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 12 Players, 199.2ms
# Speed: 1.6ms preprocess, 199.2ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 13 Players, 202.1ms
# Speed: 1.5ms preprocess, 202.1ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 13 Players, 194.8ms
# Speed: 1.8ms preprocess, 194.8ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 14 Players, 196.5ms
# Speed: 1.4ms preprocess, 196.5ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 14 Players, 197.1ms
# Speed: 1.6ms preprocess, 197.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 14 Players, 199.0ms
# Speed: 1.5ms preprocess, 199.0ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 15 Players, 195.1ms
# Speed: 1.5ms preprocess, 195.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 14 Players, 1 Main Referee, 200.8ms
# Speed: 1.6ms preprocess, 200.8ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 13 Players, 198.1ms
# Speed: 1.5ms preprocess, 198.1ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 13 Players, 198.9ms
# Speed: 1.7ms preprocess, 198.9ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 11 Players, 197.5ms
# Speed: 1.4ms preprocess, 197.5ms inference, 0.3ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 11 Players, 201.5ms
# Speed: 1.7ms preprocess, 201.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 11 Players, 276.6ms
# Speed: 1.5ms preprocess, 276.6ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 11 Players, 210.8ms
# Speed: 1.9ms preprocess, 210.8ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 11 Players, 1 Main Referee, 205.2ms
# Speed: 1.6ms preprocess, 205.2ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 11 Players, 1 Main Referee, 199.4ms
# Speed: 1.6ms preprocess, 199.4ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 10 Players, 1 Main Referee, 196.6ms
# Speed: 1.5ms preprocess, 196.6ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 9 Players, 1 Main Referee, 198.0ms
# Speed: 1.5ms preprocess, 198.0ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 11 Players, 199.0ms
# Speed: 1.5ms preprocess, 199.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 11 Players, 196.4ms
# Speed: 1.5ms preprocess, 196.4ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 10 Players, 1 Main Referee, 197.8ms
# Speed: 1.4ms preprocess, 197.8ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 10 Players, 410.4ms
# Speed: 5.1ms preprocess, 410.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 11 Players, 233.8ms
# Speed: 2.2ms preprocess, 233.8ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 10 Players, 197.1ms
# Speed: 1.5ms preprocess, 197.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 9 Players, 198.5ms
# Speed: 1.7ms preprocess, 198.5ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 9 Players, 1 Main Referee, 199.4ms
# Speed: 1.6ms preprocess, 199.4ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 7 Players, 1 Main Referee, 200.4ms
# Speed: 1.4ms preprocess, 200.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 8 Players, 1 Main Referee, 1 Staff Member, 204.0ms
# Speed: 2.2ms preprocess, 204.0ms inference, 0.3ms postprocess per image at shape (1, 3, 416, 736)
# Main referee
#
# 0: 416x736 10 Players, 198.3ms
# Speed: 1.8ms preprocess, 198.3ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 8 Players, 196.7ms
# Speed: 1.6ms preprocess, 196.7ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 10 Players, 197.3ms
# Speed: 1.4ms preprocess, 197.3ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 9 Players, 1 Staff Member, 201.6ms
# Speed: 1.8ms preprocess, 201.6ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 736)
# Main referee
#
# 0: 416x736 9 Players, 196.6ms
# Speed: 1.5ms preprocess, 196.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 10 Players, 196.8ms
# Speed: 1.7ms preprocess, 196.8ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 10 Players, 199.8ms
# Speed: 1.5ms preprocess, 199.8ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 10 Players, 196.9ms
# Speed: 1.5ms preprocess, 196.9ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 10 Players, 198.6ms
# Speed: 1.6ms preprocess, 198.6ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 10 Players, 224.9ms
# Speed: 1.6ms preprocess, 224.9ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 10 Players, 1 Staff Member, 196.7ms
# Speed: 1.5ms preprocess, 196.7ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
# Main referee
#
# 0: 416x736 10 Players, 1 Staff Member, 196.1ms
# Speed: 1.5ms preprocess, 196.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
# Main referee
#
# 0: 416x736 9 Players, 1 Staff Member, 200.7ms
# Speed: 1.8ms preprocess, 200.7ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
# Main referee
#
# 0: 416x736 9 Players, 197.7ms
# Speed: 1.5ms preprocess, 197.7ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 9 Players, 1 Staff Member, 201.1ms
# Speed: 1.4ms preprocess, 201.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
# Main referee
#
# 0: 416x736 8 Players, 1 Main Referee, 1 Staff Member, 201.6ms
# Speed: 1.5ms preprocess, 201.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
# Main referee
#
# 0: 416x736 8 Players, 1 Staff Member, 306.9ms
# Speed: 7.8ms preprocess, 306.9ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 736)
# Main referee
#
# 0: 416x736 8 Players, 1 Staff Member, 198.4ms
# Speed: 1.7ms preprocess, 198.4ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
# Main referee
#
# 0: 416x736 8 Players, 197.6ms
# Speed: 1.5ms preprocess, 197.6ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 8 Players, 1 Staff Member, 206.5ms
# Speed: 1.5ms preprocess, 206.5ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
# Main referee
#
# 0: 416x736 8 Players, 1 Staff Member, 196.0ms
# Speed: 1.5ms preprocess, 196.0ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
# Main referee
#
# 0: 416x736 8 Players, 1 Staff Member, 197.9ms
# Speed: 1.5ms preprocess, 197.9ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
# Main referee
#
# 0: 416x736 8 Players, 208.0ms
# Speed: 1.5ms preprocess, 208.0ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 7 Players, 205.3ms
# Speed: 1.4ms preprocess, 205.3ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 8 Players, 205.7ms
# Speed: 1.8ms preprocess, 205.7ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 8 Players, 196.6ms
# Speed: 1.4ms preprocess, 196.6ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 8 Players, 194.7ms
# Speed: 1.6ms preprocess, 194.7ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 9 Players, 1 Staff Member, 205.1ms
# Speed: 1.7ms preprocess, 205.1ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
# Main referee
#
# 0: 416x736 9 Players, 1 Staff Member, 189.5ms
# Speed: 1.4ms preprocess, 189.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
# Main referee
#
# 0: 416x736 9 Players, 196.3ms
# Speed: 1.5ms preprocess, 196.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 8 Players, 1 Staff Member, 198.1ms
# Speed: 1.5ms preprocess, 198.1ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
# Main referee
#
# 0: 416x736 8 Players, 1 Main Referee, 229.5ms
# Speed: 1.4ms preprocess, 229.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 9 Players, 204.7ms
# Speed: 1.4ms preprocess, 204.7ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 9 Players, 209.1ms
# Speed: 1.7ms preprocess, 209.1ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 9 Players, 197.3ms
# Speed: 1.5ms preprocess, 197.3ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 8 Players, 196.0ms
# Speed: 1.4ms preprocess, 196.0ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 8 Players, 199.6ms
# Speed: 1.5ms preprocess, 199.6ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 8 Players, 1 Staff Member, 194.3ms
# Speed: 1.7ms preprocess, 194.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
# Main referee
#
# 0: 416x736 7 Players, 1 Staff Member, 196.3ms
# Speed: 1.6ms preprocess, 196.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
# Main referee
#
# 0: 416x736 7 Players, 324.2ms
# Speed: 1.9ms preprocess, 324.2ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 7 Players, 236.3ms
# Speed: 2.0ms preprocess, 236.3ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 8 Players, 197.5ms
# Speed: 1.9ms preprocess, 197.5ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 7 Players, 1 Staff Member, 201.0ms
# Speed: 1.5ms preprocess, 201.0ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
# Main referee
#
# 0: 416x736 8 Players, 192.7ms
# Speed: 1.5ms preprocess, 192.7ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 8 Players, 193.9ms
# Speed: 1.4ms preprocess, 193.9ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 8 Players, 194.5ms
# Speed: 1.4ms preprocess, 194.5ms inference, 0.3ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 7 Players, 1 Staff Member, 194.6ms
# Speed: 1.5ms preprocess, 194.6ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
# Main referee
#
# 0: 416x736 7 Players, 1 Staff Member, 194.7ms
# Speed: 1.5ms preprocess, 194.7ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
# Main referee
#
# 0: 416x736 7 Players, 1 Staff Member, 205.2ms
# Speed: 1.6ms preprocess, 205.2ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 736)
# Main referee
#
# 0: 416x736 7 Players, 1 Staff Member, 198.0ms
# Speed: 1.7ms preprocess, 198.0ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
# Main referee
#
# 0: 416x736 6 Players, 1 Staff Member, 193.0ms
# Speed: 1.5ms preprocess, 193.0ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 736)
# Main referee
#
# 0: 416x736 5 Players, 1 Staff Member, 212.0ms
# Speed: 1.4ms preprocess, 212.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 736)
# Main referee
#
# 0: 416x736 7 Players, 1 Staff Member, 201.1ms
# Speed: 1.5ms preprocess, 201.1ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 736)
# Main referee
#
# 0: 416x736 7 Players, 193.9ms
# Speed: 1.5ms preprocess, 193.9ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 7 Players, 195.6ms
# Speed: 1.7ms preprocess, 195.6ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 736)
# Failed to read frame or end of video reached.

# %%
# change

# Aggregate labels 0 to 3, safely handling missing labels
total_0_to_3 = sum(class_detection_counts.get(label, 0) for label in range(4))  # Use .get with default value 0
average_detections_per_class = {'0-3': total_0_to_3 / frame_nbr}  # Compute average for aggregated labels

# Compute average for label 4, safely handling cases where label might not be present
average_detections_per_class['4'] = class_detection_counts.get(4, 0) / frame_nbr

print("Average number of detections per class per frame:", average_detections_per_class)

# print("Average number of detections per class per frame:", 
#       class_detection_counts[0]/frame_nbr, 
#       class_detection_counts[1]/frame_nbr, 
      
#       )
# Out:
# Average number of detections per class per frame: {'0-3': 16.78044871794872, '4': 0.08333333333333333}

# %%
class_detection_counts[2]/frame_nbr
# Out:
# 0.0018331805682859762
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import cv2
import os
import numpy as np

def create_video_from_frames(frame_folder, output_video_path, fps=30, codec='XVID'):
    # Define the codec and create VideoWriter object
    fourcc = cv2.VideoWriter_fourcc(*codec)
    frame_files = sorted([os.path.join(frame_folder, f) for f in os.listdir(frame_folder) if f.endswith('.jpg')])
    
    # Read the first frame to get the size
    first_frame = cv2.imread(frame_files[0])
    height, width, layers = first_frame.shape
    video = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

    for frame_file in frame_files:
        frame = cv2.imread(frame_file)
        video.write(frame)
    
    video.release()

# Usage
frame_folder = 'saved_frames'  # Folder containing all the frames
output_video_path = 'output_video.avi'  # Path where the output video will be saved
fps = 20  # Frames per second of the output video

create_video_from_frames(frame_folder, output_video_path, fps)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
print(cv2.__version__) #4.5.5.64
# Out:
# 4.5.5

# %%
# !pip install --upgrade opencv-python
# Out:
# Requirement already satisfied: opencv-python in /Users/othmaneechchabi/anaconda3/lib/python3.10/site-packages (4.5.5.64)
# Collecting opencv-python
#   Using cached opencv_python-4.9.0.80-cp37-abi3-macosx_11_0_arm64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in /Users/othmaneechchabi/anaconda3/lib/python3.10/site-packages (from opencv-python) (1.24.3)
# Using cached opencv_python-4.9.0.80-cp37-abi3-macosx_11_0_arm64.whl (35.4 MB)
# Installing collected packages: opencv-python
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.5.5.64
#     Uninstalling opencv-python-4.5.5.64:
#       Successfully uninstalled opencv-python-4.5.5.64
# Successfully installed opencv-python-4.9.0.80

# %%
# !pip install opencv-python==4.5.5.64
# Out:
# Collecting opencv-python==4.5.5.64
#   Using cached opencv_python-4.5.5.64-cp37-abi3-macosx_11_0_arm64.whl.metadata (18 kB)
# Requirement already satisfied: numpy>=1.21.2 in /Users/othmaneechchabi/anaconda3/lib/python3.10/site-packages (from opencv-python==4.5.5.64) (1.24.3)
# Using cached opencv_python-4.5.5.64-cp37-abi3-macosx_11_0_arm64.whl (29.9 MB)
# Installing collected packages: opencv-python
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.9.0.80
#     Uninstalling opencv-python-4.9.0.80:
#       Successfully uninstalled opencv-python-4.9.0.80
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ultralytics 8.2.2 requires opencv-python>=4.6.0, but you have opencv-python 4.5.5.64 which is incompatible.
# Successfully installed opencv-python-4.5.5.64
